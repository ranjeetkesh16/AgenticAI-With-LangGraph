# %% [markdown]
# ## plan trip with flight search & feedabck for the trip

# %%
from typing import TypedDict, Optional
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import MemorySaver
from langchain_openai import ChatOpenAI
from langchain.schema import HumanMessage
from langgraph.types import interrupt, Command
import uuid
import os

class TripState(TypedDict):
    starting_point: Optional[str]
    destination: Optional[str]
    budget: Optional[str]
    duration: Optional[str]
    proposed_plan: Optional[str]
    satisfied_with_plan: Optional[bool]
    done: Optional[bool]
    selected_flight: Optional[str]
    flight_source: Optional[str]
    flight_destination: Optional[str]
    flight_date: Optional[str]
    return_trip: Optional[bool]
    available_flights: Optional[list]

def get_groq_llm():
    return ChatOpenAI(
        model="openai/gpt-oss-20b",
        base_url="https://api.groq.com/openai/v1",
        api_key=os.getenv("GROQ_API_KEY"),
        temperature=0.7, max_tokens=2000
    )

llm = get_groq_llm()
FIELDS = ["starting_point", "destination", "budget", "duration"]
FIELD_QS = {
    "starting_point": "Ask the user for their trip starting location in a friendly way.",
    "destination": "Ask the user where they'd like to travel, naturally.",
    "budget": "Ask the user what budget they'd like to set for the trip, friendly and casual.",
    "duration": "Ask, in a conversational style, how many days they want their trip to last."
}

def generate_slot_question(slot_name):
    print("Entering generate_slot_question")
    prompt = FIELD_QS[slot_name]
    response = llm.invoke(prompt)
    print(f"DEBUG: Generated question for '{slot_name}': {response}")
    return response

def extract_slot_value(slot_name, user_input):
    print("Entering extract_slot_value")
    prompt = (
        f"You are a smart assistant filling out a travel form.\n"
        f"The user was asked to specify their '{slot_name.replace('_', ' ')}'.\n"
        f"User replied: \"{user_input}\"\n"
        f"Extract and reply with ONLY the value for '{slot_name}'. If no clear value is found, reply 'None'."
    )
    response = llm.invoke(prompt)
    if response.lower() == "none":
        response = None
    print(f"DEBUG: Extracted value for {slot_name}: '{response}'")
    return response

def extract_change_field(user_input: str) -> Optional[str]:
    print("Entering extract_change_field")
    prompt = (
        "Decide which of these trip fields (if any) the user wants to update: "
        "starting_point, destination, budget, duration.\n"
        f"User said: \"{user_input}\"\n"
        "Reply ONLY with the field name (starting_point, destination, budget, duration) if you detect it, or 'proceed' if approval."
    )
    result = llm.invoke(prompt)
    print(f"DEBUG: LLM slot change extraction: '{result}'")
    for f in FIELDS:
        if f in result:
            return f
    if "proceed" in result or "ok" in result or "yes" in result:
        return "proceed"
    return None

def ask_starting_point(state: TripState) -> TripState:
    print("DEBUG: Entering ask_starting_point with state")
    if not state.get("starting_point"):
        q = generate_slot_question("starting_point")
        user_input = interrupt(q)
        value = extract_slot_value("starting_point", user_input)
        state["starting_point"] = value
    return state

def ask_destination(state: TripState) -> TripState:
    print("DEBUG: Entering ask_destination with state")
    if not state.get("destination"):
        q = generate_slot_question("destination")
        user_input = interrupt(q)
        value = extract_slot_value("destination", user_input)
        state["destination"] = value
    return state

def ask_budget(state: TripState) -> TripState:
    print("DEBUG: Entering ask_budget with state")
    if not state.get("budget"):
        q = generate_slot_question("budget")
        user_input = interrupt(q)
        value = extract_slot_value("budget", user_input)
        state["budget"] = value
    return state

def ask_duration(state: TripState) -> TripState:
    print("DEBUG: Entering ask_duration with state")
    if not state.get("duration"):
        q = generate_slot_question("duration")
        user_input = interrupt(q)
        value = extract_slot_value("duration", user_input)
        state["duration"] = value
    return state

def review_info(state: TripState) -> TripState:
    print("DEBUG: Entering review_info with state", state)
    summary = (
        f"Please review your trip details:\n"
        f"- Starting point: {state['starting_point']}\n"
        f"- Destination: {state['destination']}\n"
        f"- Budget: {state['budget']}\n"
        f"- Duration: {state['duration']}\n"
        "Reply 'proceed' to confirm, or naturally say what you'd like to change."
    )
    answer = interrupt(summary)
    print(f"DEBUG: Got answer for review: {answer}")
    change_field = extract_change_field(answer)
    print(f"DEBUG: type of change_field: {type(change_field)}")
    print(f"DEBUG: LLM extracted in review_info: {change_field}")
    
    if change_field == "proceed":
        return state
    elif change_field in FIELDS:
        state[change_field] = None
        # Defensive: reset plan approval flag so approval loop is always clean
        state['satisfied_with_plan'] = None
        return state
    else:
        print("DEBUG: Could not parse field to change; ask again.")
        return review_info(state)

def review_router(state: TripState):
    print("DEBUG: In review_router with state", state)
    missing = [fld for fld in FIELDS if not state.get(fld)]
    print(f"DEBUG: In review_router, missing fields: {missing}")
    if len(missing)>0:
        return "review_info"
    return "plan_trip"

def plan_trip(state: TripState) -> TripState:
    print("DEBUG: Entering plan_trip with state", state)
    # Defensive: always reset approval flag before generating a new plan
    state['satisfied_with_plan'] = None
    prompt = (
        f"Can you plan a fun, friendly, {state['duration']}-day itinerary from {state['starting_point']} "
        f"to {state['destination']} with a budget of {state['budget']}?"
    )
    result = llm([HumanMessage(content=prompt)])
    print(f"\nYour itinerary:\n{result.content}\n")
    state['proposed_plan'] = result.content
    return state

def plan_approval(state: TripState) -> TripState:
    print("DEBUG: Entering plan_approval with state", state)
    review = (
        f"Here’s your trip plan:\n\n{state.get('proposed_plan','none')}\n\n"
        "Are you satisfied? Type 'yes' to book flights, or request changes."
    )
    user_input = interrupt(review)
    change_field = extract_change_field(user_input)
    print("DEBUG: LLM approval/feedback extraction:", change_field)
    print(f"DEBUG: type of change_field: {type(change_field)}")
    print(f"DEBUG: LLM extracted in plan_approval: {change_field}")
    if change_field == "proceed":
        state['satisfied_with_plan'] = True
    elif change_field in FIELDS:
        state[change_field] = None
        state['satisfied_with_plan'] = None
    else:
        state['satisfied_with_plan'] = None
    return state

def plan_approval_router(state: TripState):
    print(f"DEBUG: In plan_approval_router, satisfied_with_plan={state.get('satisfied_with_plan')}")
    if state.get("satisfied_with_plan"):
        print("DEBUG: Plan approved; moving to flight booking.")
        return "ask_flight_details"
    missing = [fld for fld in FIELDS if not state.get(fld)]
    if len(missing)>0:
        print(f"DEBUG: Editing slot(s) {missing}; will re-review.")
        return "review_info"
    print("DEBUG: General feedback; re-planning.")
    return "plan_trip"

def ask_flight_details(state: TripState) -> TripState:
    print("DEBUG: Entering ask_flight_details with state", state)
    src = interrupt(f"To book your flight, please confirm your departure city (or edit): [{state['starting_point']}]")
    dst = interrupt(f"And your arrival city? [{state['destination']}]")
    date = interrupt("On what date would you like to depart? (YYYY-MM-DD)")
    ret_type = interrupt("Is this a one-way or round-trip? (Type 'one-way' or 'round-trip')")
    state['flight_source'] = src or state['starting_point']
    state['flight_destination'] = dst or state['destination']
    state['flight_date'] = date
    state['return_trip'] = "round" in ret_type.lower()
    return state

def fetch_flights(state: TripState) -> TripState:
    print(f"DEBUG: Fetching flights {state['flight_source']} → {state['flight_destination']} on {state['flight_date']} (return: {state['return_trip']})")
    # Simulate options for DEMO
    state['available_flights'] = [
        "AI101 | 8:00-10:30 | ₹6,300",
        "6E205 | 12:10-14:30 | ₹5,950",
        "G8 302 | 18:45-21:15 | ₹6,010"
    ]
    opts = "\n".join([f"{i+1}. {f}" for i, f in enumerate(state['available_flights'])])
    sel = interrupt(f"Here are some flight options:\n{opts}\nSelect a flight number:")
    try:
        ix = int(sel) - 1
        state['selected_flight'] = state['available_flights'][ix]
        print(f"DEBUG: User selected flight: {state['selected_flight']}")
    except Exception:
        state['selected_flight'] = None
        print("DEBUG: Invalid flight selection!")
    return state

def booking_confirmation(state: TripState) -> TripState:
    print("DEBUG: Entering booking_confirmation with state", state)
    if state.get("selected_flight"):
        print(f"\nBooking confirmed for: {state['selected_flight']}")
        state['done'] = True
    else:
        print("No flight selected. Ending flow.")
        state['done'] = True
    return state

graph = StateGraph(TripState)
graph.add_node("ask_starting_point", ask_starting_point)
graph.add_node("ask_destination", ask_destination)
graph.add_node("ask_budget", ask_budget)
graph.add_node("ask_duration", ask_duration)
graph.add_node("review_info", review_info)
graph.add_node("plan_trip", plan_trip)
graph.add_node("plan_approval", plan_approval)
graph.add_node("ask_flight_details", ask_flight_details)
graph.add_node("fetch_flights", fetch_flights)
graph.add_node("booking_confirmation", booking_confirmation)

graph.set_entry_point("ask_starting_point")
graph.add_edge("ask_starting_point", "ask_destination")
graph.add_edge("ask_destination", "ask_budget")
graph.add_edge("ask_budget", "ask_duration")
graph.add_edge("ask_duration", "review_info")
graph.add_conditional_edges(
    "review_info", review_router, {"review_info": "review_info", "plan_trip": "plan_trip"}
)
graph.add_edge("plan_trip", "plan_approval")
graph.add_conditional_edges(
    "plan_approval", plan_approval_router,
    {
        "plan_trip": "plan_trip",
        "ask_flight_details": "ask_flight_details",
        "review_info": "review_info"
    }
)
graph.add_edge("ask_flight_details", "fetch_flights")
graph.add_edge("fetch_flights", "booking_confirmation")
graph.add_edge("booking_confirmation", END)

checkpointer = MemorySaver()
workflow = graph.compile(checkpointer=checkpointer)




from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

display(
    Image(
        workflow.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
THREAD_ID = str(uuid.uuid4())
config = {"configurable": {"thread_id": THREAD_ID}}
state = {}
print("Bot: Hi there! Let's plan your trip together.")

while True:
    result = workflow.invoke(state, config)
    print(f"DEBUG State: {state}")
    print(f"DEBUG Result: {result}")

    if result.get("done"):
        print("-- Trip planning complete! --")
        break

    if "__interrupt__" in result:
        prompt = result["__interrupt__"][0].value
        user_input = input(prompt + " ")
        state = workflow.invoke(Command(resume=user_input), config)
        continue

    print("DEBUG: Workflow reached END, exiting.")
    break
# Out:
# Bot: Hi there! Let's plan your trip together.
# DEBUG: Entering ask_starting_point with state
# Entering generate_slot_question
# DEBUG: Generated question for 'starting_point': Sure thing! Where are you starting your trip from? 🌍
# DEBUG State: {}
# DEBUG Result: {'__interrupt__': [Interrupt(value='Sure thing! Where are you starting your trip from? 🌍', id='0bf0a96bed72890afea9bafb3d999605')]}
# DEBUG: Entering ask_starting_point with state
# Entering generate_slot_question
# DEBUG: Generated question for 'starting_point': Sure thing! Where are you starting your trip from? 🚗✈️
# Entering extract_slot_value
# DEBUG: Extracted value for starting_point: 'mumbai'
# DEBUG: Entering ask_destination with state
# Entering generate_slot_question
# DEBUG: Generated question for 'destination': Sure thing! Where would you like to travel? 🌍✈️
# DEBUG: Entering ask_starting_point with state
# DEBUG: Entering ask_destination with state
# Entering generate_slot_question
# DEBUG: Generated question for 'destination': Where would you like to travel to? 🌍✈️
# DEBUG State: {'starting_point': 'mumbai', '__interrupt__': [Interrupt(value='Sure thing! Where would you like to travel? 🌍✈️', id='1b9edf83f72132a8fed5a1a377a184a5')]}
# DEBUG Result: {'starting_point': 'mumbai', '__interrupt__': [Interrupt(value='Where would you like to travel to? 🌍✈️', id='956f5e9f181a8567b03006b6cff8bdc4')]}
# DEBUG: Entering ask_destination with state
# Entering generate_slot_question
# DEBUG: Generated question for 'destination': Where would you love to travel to?
# Entering extract_slot_value
# DEBUG: Extracted value for destination: 'goa'
# DEBUG: Entering ask_budget with state
# Entering generate_slot_question
# DEBUG: Generated question for 'budget': Hey, just to make sure we’re on the same page—what budget are you thinking of setting for this trip? Feel free to give a rough range or a specific number. 🚀
# DEBUG: Entering ask_starting_point with state
# DEBUG: Entering ask_destination with state
# DEBUG: Entering ask_budget with state
# Entering generate_slot_question
# DEBUG: Generated question for 'budget': Hey! Just to make sure we plan something that fits your wallet, what budget are you thinking for the trip? Feel free to give a rough range or a specific amount—whatever works best for you!
# DEBUG State: {'starting_point': 'mumbai', 'destination': 'goa', '__interrupt__': [Interrupt(value='Hey, just to make sure we’re on the same page—what budget are you thinking of setting for this trip? Feel free to give a rough range or a specific number. 🚀', id='691e52e8226c41d9a2af634d6f5cc3d1')]}
# DEBUG Result: {'starting_point': 'mumbai', 'destination': 'goa', '__interrupt__': [Interrupt(value='Hey! Just to make sure we plan something that fits your wallet, what budget are you thinking for the trip? Feel free to give a rough range or a specific amount—whatever works best for you!', id='0f1fe24bec31a7506674be3e13ba7a9b')]}
# DEBUG: Entering ask_budget with state
# Entering generate_slot_question
# DEBUG: Generated question for 'budget': What budget are you thinking of setting for the trip?  Feel free to give a rough number or a range—whatever works best for you!
# Entering extract_slot_value
# DEBUG: Extracted value for budget: '20000'
# DEBUG: Entering ask_duration with state
# Entering generate_slot_question
# DEBUG: Generated question for 'duration': How many days would you like your trip to last?
# DEBUG: Entering ask_starting_point with state
# DEBUG: Entering ask_destination with state
# DEBUG: Entering ask_budget with state
# DEBUG: Entering ask_duration with state
# Entering generate_slot_question
# DEBUG: Generated question for 'duration': Sure thing! How many days would you like your trip to last? 🌍✈️
# DEBUG State: {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '20000', '__interrupt__': [Interrupt(value='How many days would you like your trip to last?', id='8325388eafadb756d30f71b56b2cc2df')]}
# DEBUG Result: {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '20000', '__interrupt__': [Interrupt(value='Sure thing! How many days would you like your trip to last? 🌍✈️', id='d7e30af5e75b1305176948e021136f44')]}
# DEBUG: Entering ask_duration with state
# Entering generate_slot_question
# DEBUG: Generated question for 'duration': Sure thing! How many days are you thinking of for your trip?
# Entering extract_slot_value
# DEBUG: Extracted value for duration: '3 days'
# DEBUG: Entering review_info with state {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '20000', 'duration': '3 days'}
# DEBUG: Entering ask_starting_point with state
# DEBUG: Entering ask_destination with state
# DEBUG: Entering ask_budget with state
# DEBUG: Entering ask_duration with state
# DEBUG: Entering review_info with state {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '20000', 'duration': '3 days'}
# DEBUG State: {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '20000', 'duration': '3 days', '__interrupt__': [Interrupt(value="Please review your trip details:\n- Starting point: mumbai\n- Destination: goa\n- Budget: 20000\n- Duration: 3 days\nReply 'proceed' to confirm, or naturally say what you'd like to change.", id='3dce53e310000a1e9e2fce4bb1e15e2e')]}
# DEBUG Result: {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '20000', 'duration': '3 days', '__interrupt__': [Interrupt(value="Please review your trip details:\n- Starting point: mumbai\n- Destination: goa\n- Budget: 20000\n- Duration: 3 days\nReply 'proceed' to confirm, or naturally say what you'd like to change.", id='14d1e18a26712cca0083bd4e7852003a')]}
# DEBUG: Entering review_info with state {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '20000', 'duration': '3 days'}
# DEBUG: Got answer for review: let's change the budget
# Entering extract_change_field
# DEBUG: LLM slot change extraction: 'budget'
# DEBUG: type of change_field: <class 'str'>
# DEBUG: LLM extracted in review_info: budget
# DEBUG: In review_router with state {'starting_point': 'mumbai', 'destination': 'goa', 'budget': None, 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: In review_router, missing fields: ['budget']
# DEBUG: Entering review_info with state {'starting_point': 'mumbai', 'destination': 'goa', 'budget': None, 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: Entering ask_starting_point with state
# DEBUG: Entering ask_destination with state
# DEBUG: Entering ask_budget with state
# Entering generate_slot_question
# DEBUG: Generated question for 'budget': Hey there! Just wondering, what kind of budget are you thinking about setting for this trip? 😊
# DEBUG State: {'starting_point': 'mumbai', 'destination': 'goa', 'budget': None, 'duration': '3 days', 'satisfied_with_plan': None, '__interrupt__': [Interrupt(value="Please review your trip details:\n- Starting point: mumbai\n- Destination: goa\n- Budget: None\n- Duration: 3 days\nReply 'proceed' to confirm, or naturally say what you'd like to change.", id='989e8473ff5186952784922c7966c1a9')]}
# DEBUG Result: {'starting_point': 'mumbai', 'destination': 'goa', 'budget': None, 'duration': '3 days', 'satisfied_with_plan': None, '__interrupt__': [Interrupt(value='Hey there! Just wondering, what kind of budget are you thinking about setting for this trip? 😊', id='68ef802687756629cc2fd9b79bd14c7e')]}
# DEBUG: Entering ask_budget with state
# Entering generate_slot_question
# DEBUG: Generated question for 'budget': Sure thing! What kind of budget are you thinking about for this trip? Feel free to give me a rough number or a range that works for you. 😊
# Entering extract_slot_value
# DEBUG: Extracted value for budget: '15000'
# DEBUG: Entering ask_duration with state
# DEBUG: Entering review_info with state {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: Entering ask_starting_point with state
# DEBUG: Entering ask_destination with state
# DEBUG: Entering ask_budget with state
# DEBUG: Entering ask_duration with state
# DEBUG: Entering review_info with state {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG State: {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'satisfied_with_plan': None, '__interrupt__': [Interrupt(value="Please review your trip details:\n- Starting point: mumbai\n- Destination: goa\n- Budget: 15000\n- Duration: 3 days\nReply 'proceed' to confirm, or naturally say what you'd like to change.", id='ce293cb73fa6f35ccb2cfc0e033840bb')]}
# DEBUG Result: {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'satisfied_with_plan': None, '__interrupt__': [Interrupt(value="Please review your trip details:\n- Starting point: mumbai\n- Destination: goa\n- Budget: 15000\n- Duration: 3 days\nReply 'proceed' to confirm, or naturally say what you'd like to change.", id='460b0934acc74255f420501c6e8936ac')]}
# DEBUG: Entering review_info with state {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: Got answer for review: proceed
# Entering extract_change_field
# DEBUG: LLM slot change extraction: 'proceed'
# DEBUG: type of change_field: <class 'str'>
# DEBUG: LLM extracted in review_info: proceed
# DEBUG: In review_router with state {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: In review_router, missing fields: []
# DEBUG: Entering plan_trip with state {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'satisfied_with_plan': None}
#
# Your itinerary:
# ## 3‑Day Mumbai‑to‑Goa Itinerary
# **Budget:** ₹15 000 (≈ $200)
# **Tone:** Fun, friendly, “just the right amount of adventure”
#
# > **Tip:** Book everything at least 2–3 weeks in advance to snag the best rates (especially trains/buses and hostels).
#
# ---
#
# | Day | Time | What to Do | Where | Cost | Notes |
# |-----|------|------------|-------|------|-------|
# | **Day 1** | **Morning** | **Leave Mumbai** | Train/Bus (Mumbai‑Goa) | ₹800 (bus) or ₹1 200 (passenger train) | If you’re a night‑owl, catch a late‑night train (≈ 10 h) and arrive early in Goa. |
# | | **Afternoon** | **Check‑in & Lunch** | Budget guesthouse/hostel near Calangute | ₹1 500 (2‑bedroom dorm) | Grab a local thali or a veggie wrap – around ₹150. |
# | | **Afternoon** | **Beach Time** | Calangute & Baga | Free | Sunset at Baga Beach is a must‑see. |
# | | **Evening** | **Dinner & Night Market** | Mapusa Night Market | ₹200 | Try the famous “Prawns with coconut milk” (≈ ₹150). |
# | | **Night** | **Relax / Light Walk** | Calangute | Free | Grab a cold coconut water (₹30). |
# | **Day 2** | **Morning** | **Scooter Rental** | Rental shop near hotel | ₹300 | 24‑hr scooter, 3 km/100 km. |
# | | **Morning** | **Explore North Goa** | Anjuna, Vagator | Free | Wander the flea markets, beach shacks. |
# | | **Mid‑day** | **Lunch** | Local shack | ₹120 | “Goan fish curry” with rice. |
# | | **Afternoon** | **Water‑Sports** | Calangute or Baga | ₹1 000 | Parasailing + banana boat combo (budget). |
# | | **Late‑afternoon** | **Sunset at Chapora Fort** | Chapora Fort | Free | Great photo ops. |
# | | **Evening** | **Dinner** | Panjim (downtown) | ₹200 | Try “Prawn Curry” at a local restaurant. |
# | | **Night** | **Club/Bar** | Tito’s or Mambo’s | ₹300 (drink) | If you’re up for a bit of nightlife. |
# | **Day 3** | **Morning** | **South Goa** | Palolem or Agonda | Free | Relaxing beaches, less crowded. |
# | | **Mid‑day** | **Lunch** | Beach shack | ₹120 | “Goan Fish Tacos” (₹120). |
# | | **Afternoon** | **Dudhsagar Falls** | (Optional day‑trip) | ₹1 500 (bus + entry) | Book a local tour; includes lunch. |
# | | **Late‑afternoon** | **Return to Mumbai** | Train/Bus | ₹800 | Leave by 4 pm to catch the evening train. |
# | | **Night** | **Arrival in Mumbai** | | | |
#
# ---
#
# ## Cost Breakdown (₹)
#
# | Category | Cost | Notes |
# |----------|------|-------|
# | **Transport (Mumbai‑Goa)** | ₹800 | Bus (cheapest) |
# | **Accommodation (2 nights)** | ₹1 500 | Dorm room or budget guesthouse |
# | **Food (3 days)** | ₹2 400 | 3 meals/day at ₹300–₹400 |
# | **Activities (Water‑sports, Fort entry)** | ₹1 500 | Parasailing + entry fees |
# | **Scooter Rental** | ₹300 | 24‑hr |
# | **Miscellaneous (Souvenirs, extra drinks)** | ₹500 | Buffer |
# | **Total** | **₹7 500** | **Leaves ₹7 500 for flexibility** |
#
# > **Why we’re under budget?**
# > - Staying in dorms/guesthouses keeps lodging cheap.
# > - Eating at beach shacks or local thalis cuts food costs.
# > - Most beaches are free; only the water‑sports and Dudhsagar trip cost extra.
#
# ---
#
# ## Packing Checklist
#
# | Item | Why |
# |------|-----|
# | Light, breathable clothing | Goa is hot & humid |
# | Swimwear & towel | Beach days |
# | Sunscreen (SPF 50+) | Protect skin |
# | Hat & sunglasses | UV protection |
# | Flip‑flops & sandals | Beach & casual |
# | Light rain jacket | Monsoon season |
# | Small backpack | Carry snacks, water |
# | Power bank | Phone & camera |
# | Reusable water bottle | Stay hydrated |
#
# ---
#
# ## Safety & Tips
#
# | Tip | Explanation |
# |-----|-------------|
# | **Book train/bus tickets early** | Prices rise close to departure. |
# | **Stay in a well‑rated hostel** | Read recent reviews for safety. |
# | **Use licensed scooter rentals** | Verify insurance & helmet. |
# | **Avoid sharing water bottles** | Prevent water‑borne illnesses. |
# | **Keep valuables in a hotel safe** | Most hostels have them. |
# | **Stay hydrated** | Carry water and drink often. |
# | **Respect local customs** | Dress modestly when visiting temples. |
#
# ---
#
# ## Optional Upgrades (If you want to splurge a bit)
#
# | Upgrade | Approx. Cost | Benefit |
# |---------|--------------|---------|
# | **Premium train (AC)** | +₹2 000 | Faster, comfortable |
# | **Private scooter rental** | +₹200 | More privacy |
# | **Fine‑dining dinner** | +₹500 | Taste of Goan fine cuisine |
# | **Night club entry** | +₹400 | Full nightlife experience |
# | **Spa treatment** | +₹800 | Relax after a long trip |
#
# ---
#
# ### Final Thought
#
# With just ₹15 000 you can enjoy a memorable 3‑day escape from Mumbai to Goa, soaking up beaches, local food, and a bit of adventure—without breaking the bank. Have a blast, stay safe, and enjoy every wave! 🌊✈️🍹
#
# DEBUG: Entering plan_approval with state {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'proposed_plan': '## 3‑Day Mumbai‑to‑Goa Itinerary  \n**Budget:** ₹15\u202f000 (≈\u202f$200)  \n**Tone:** Fun, friendly, “just the right amount of adventure”  \n\n> **Tip:** Book everything at least 2–3\u202fweeks in advance to snag the best rates (especially trains/buses and hostels).  \n\n---\n\n| Day | Time | What to Do | Where | Cost | Notes |\n|-----|------|------------|-------|------|-------|\n| **Day\u202f1** | **Morning** | **Leave Mumbai** | Train/Bus (Mumbai‑Goa) | ₹800 (bus) or ₹1\u202f200 (passenger train) | If you’re a night‑owl, catch a late‑night train (≈\u202f10\u202fh) and arrive early in Goa. |\n| | **Afternoon** | **Check‑in & Lunch** | Budget guesthouse/hostel near Calangute | ₹1\u202f500 (2‑bedroom dorm) | Grab a local thali or a veggie wrap – around ₹150. |\n| | **Afternoon** | **Beach Time** | Calangute & Baga | Free | Sunset at Baga Beach is a must‑see. |\n| | **Evening** | **Dinner & Night Market** | Mapusa Night Market | ₹200 | Try the famous “Prawns with coconut milk” (≈\u202f₹150). |\n| | **Night** | **Relax / Light Walk** | Calangute | Free | Grab a cold coconut water (₹30). |\n| **Day\u202f2** | **Morning** | **Scooter Rental** | Rental shop near hotel | ₹300 | 24‑hr scooter, 3\u202fkm/100\u202fkm. |\n| | **Morning** | **Explore North Goa** | Anjuna, Vagator | Free | Wander the flea markets, beach shacks. |\n| | **Mid‑day** | **Lunch** | Local shack | ₹120 | “Goan fish curry” with rice. |\n| | **Afternoon** | **Water‑Sports** | Calangute or Baga | ₹1\u202f000 | Parasailing + banana boat combo (budget). |\n| | **Late‑afternoon** | **Sunset at Chapora Fort** | Chapora Fort | Free | Great photo ops. |\n| | **Evening** | **Dinner** | Panjim (downtown) | ₹200 | Try “Prawn Curry” at a local restaurant. |\n| | **Night** | **Club/Bar** | Tito’s or Mambo’s | ₹300 (drink) | If you’re up for a bit of nightlife. |\n| **Day\u202f3** | **Morning** | **South Goa** | Palolem or Agonda | Free | Relaxing beaches, less crowded. |\n| | **Mid‑day** | **Lunch** | Beach shack | ₹120 | “Goan Fish Tacos” (₹120). |\n| | **Afternoon** | **Dudhsagar Falls** | (Optional day‑trip) | ₹1\u202f500 (bus + entry) | Book a local tour; includes lunch. |\n| | **Late‑afternoon** | **Return to Mumbai** | Train/Bus | ₹800 | Leave by 4\u202fpm to catch the evening train. |\n| | **Night** | **Arrival in Mumbai** | | | |\n\n---\n\n## Cost Breakdown (₹)\n\n| Category | Cost | Notes |\n|----------|------|-------|\n| **Transport (Mumbai‑Goa)** | ₹800 | Bus (cheapest) |\n| **Accommodation (2 nights)** | ₹1\u202f500 | Dorm room or budget guesthouse |\n| **Food (3 days)** | ₹2\u202f400 | 3 meals/day at ₹300–₹400 |\n| **Activities (Water‑sports, Fort entry)** | ₹1\u202f500 | Parasailing + entry fees |\n| **Scooter Rental** | ₹300 | 24‑hr |\n| **Miscellaneous (Souvenirs, extra drinks)** | ₹500 | Buffer |\n| **Total** | **₹7\u202f500** | **Leaves ₹7\u202f500 for flexibility** |\n\n> **Why we’re under budget?**  \n> - Staying in dorms/guesthouses keeps lodging cheap.  \n> - Eating at beach shacks or local thalis cuts food costs.  \n> - Most beaches are free; only the water‑sports and Dudhsagar trip cost extra.\n\n---\n\n## Packing Checklist\n\n| Item | Why |\n|------|-----|\n| Light, breathable clothing | Goa is hot & humid |\n| Swimwear & towel | Beach days |\n| Sunscreen (SPF\u202f50+) | Protect skin |\n| Hat & sunglasses | UV protection |\n| Flip‑flops & sandals | Beach & casual |\n| Light rain jacket | Monsoon season |\n| Small backpack | Carry snacks, water |\n| Power bank | Phone & camera |\n| Reusable water bottle | Stay hydrated |\n\n---\n\n## Safety & Tips\n\n| Tip | Explanation |\n|-----|-------------|\n| **Book train/bus tickets early** | Prices rise close to departure. |\n| **Stay in a well‑rated hostel** | Read recent reviews for safety. |\n| **Use licensed scooter rentals** | Verify insurance & helmet. |\n ...
# DEBUG: Entering ask_starting_point with state
# DEBUG: Entering ask_destination with state
# DEBUG: Entering ask_budget with state
# DEBUG: Entering ask_duration with state
# DEBUG: Entering review_info with state {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'proposed_plan': '## 3‑Day Mumbai‑to‑Goa Itinerary  \n**Budget:** ₹15\u202f000 (≈\u202f$200)  \n**Tone:** Fun, friendly, “just the right amount of adventure”  \n\n> **Tip:** Book everything at least 2–3\u202fweeks in advance to snag the best rates (especially trains/buses and hostels).  \n\n---\n\n| Day | Time | What to Do | Where | Cost | Notes |\n|-----|------|------------|-------|------|-------|\n| **Day\u202f1** | **Morning** | **Leave Mumbai** | Train/Bus (Mumbai‑Goa) | ₹800 (bus) or ₹1\u202f200 (passenger train) | If you’re a night‑owl, catch a late‑night train (≈\u202f10\u202fh) and arrive early in Goa. |\n| | **Afternoon** | **Check‑in & Lunch** | Budget guesthouse/hostel near Calangute | ₹1\u202f500 (2‑bedroom dorm) | Grab a local thali or a veggie wrap – around ₹150. |\n| | **Afternoon** | **Beach Time** | Calangute & Baga | Free | Sunset at Baga Beach is a must‑see. |\n| | **Evening** | **Dinner & Night Market** | Mapusa Night Market | ₹200 | Try the famous “Prawns with coconut milk” (≈\u202f₹150). |\n| | **Night** | **Relax / Light Walk** | Calangute | Free | Grab a cold coconut water (₹30). |\n| **Day\u202f2** | **Morning** | **Scooter Rental** | Rental shop near hotel | ₹300 | 24‑hr scooter, 3\u202fkm/100\u202fkm. |\n| | **Morning** | **Explore North Goa** | Anjuna, Vagator | Free | Wander the flea markets, beach shacks. |\n| | **Mid‑day** | **Lunch** | Local shack | ₹120 | “Goan fish curry” with rice. |\n| | **Afternoon** | **Water‑Sports** | Calangute or Baga | ₹1\u202f000 | Parasailing + banana boat combo (budget). |\n| | **Late‑afternoon** | **Sunset at Chapora Fort** | Chapora Fort | Free | Great photo ops. |\n| | **Evening** | **Dinner** | Panjim (downtown) | ₹200 | Try “Prawn Curry” at a local restaurant. |\n| | **Night** | **Club/Bar** | Tito’s or Mambo’s | ₹300 (drink) | If you’re up for a bit of nightlife. |\n| **Day\u202f3** | **Morning** | **South Goa** | Palolem or Agonda | Free | Relaxing beaches, less crowded. |\n| | **Mid‑day** | **Lunch** | Beach shack | ₹120 | “Goan Fish Tacos” (₹120). |\n| | **Afternoon** | **Dudhsagar Falls** | (Optional day‑trip) | ₹1\u202f500 (bus + entry) | Book a local tour; includes lunch. |\n| | **Late‑afternoon** | **Return to Mumbai** | Train/Bus | ₹800 | Leave by 4\u202fpm to catch the evening train. |\n| | **Night** | **Arrival in Mumbai** | | | |\n\n---\n\n## Cost Breakdown (₹)\n\n| Category | Cost | Notes |\n|----------|------|-------|\n| **Transport (Mumbai‑Goa)** | ₹800 | Bus (cheapest) |\n| **Accommodation (2 nights)** | ₹1\u202f500 | Dorm room or budget guesthouse |\n| **Food (3 days)** | ₹2\u202f400 | 3 meals/day at ₹300–₹400 |\n| **Activities (Water‑sports, Fort entry)** | ₹1\u202f500 | Parasailing + entry fees |\n| **Scooter Rental** | ₹300 | 24‑hr |\n| **Miscellaneous (Souvenirs, extra drinks)** | ₹500 | Buffer |\n| **Total** | **₹7\u202f500** | **Leaves ₹7\u202f500 for flexibility** |\n\n> **Why we’re under budget?**  \n> - Staying in dorms/guesthouses keeps lodging cheap.  \n> - Eating at beach shacks or local thalis cuts food costs.  \n> - Most beaches are free; only the water‑sports and Dudhsagar trip cost extra.\n\n---\n\n## Packing Checklist\n\n| Item | Why |\n|------|-----|\n| Light, breathable clothing | Goa is hot & humid |\n| Swimwear & towel | Beach days |\n| Sunscreen (SPF\u202f50+) | Protect skin |\n| Hat & sunglasses | UV protection |\n| Flip‑flops & sandals | Beach & casual |\n| Light rain jacket | Monsoon season |\n| Small backpack | Carry snacks, water |\n| Power bank | Phone & camera |\n| Reusable water bottle | Stay hydrated |\n\n---\n\n## Safety & Tips\n\n| Tip | Explanation |\n|-----|-------------|\n| **Book train/bus tickets early** | Prices rise close to departure. |\n| **Stay in a well‑rated hostel** | Read recent reviews for safety. |\n| **Use licensed scooter rentals** | Verify insurance & helmet. |\n|  ...
# DEBUG State: {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'proposed_plan': '## 3‑Day Mumbai‑to‑Goa Itinerary  \n**Budget:** ₹15\u202f000 (≈\u202f$200)  \n**Tone:** Fun, friendly, “just the right amount of adventure”  \n\n> **Tip:** Book everything at least 2–3\u202fweeks in advance to snag the best rates (especially trains/buses and hostels).  \n\n---\n\n| Day | Time | What to Do | Where | Cost | Notes |\n|-----|------|------------|-------|------|-------|\n| **Day\u202f1** | **Morning** | **Leave Mumbai** | Train/Bus (Mumbai‑Goa) | ₹800 (bus) or ₹1\u202f200 (passenger train) | If you’re a night‑owl, catch a late‑night train (≈\u202f10\u202fh) and arrive early in Goa. |\n| | **Afternoon** | **Check‑in & Lunch** | Budget guesthouse/hostel near Calangute | ₹1\u202f500 (2‑bedroom dorm) | Grab a local thali or a veggie wrap – around ₹150. |\n| | **Afternoon** | **Beach Time** | Calangute & Baga | Free | Sunset at Baga Beach is a must‑see. |\n| | **Evening** | **Dinner & Night Market** | Mapusa Night Market | ₹200 | Try the famous “Prawns with coconut milk” (≈\u202f₹150). |\n| | **Night** | **Relax / Light Walk** | Calangute | Free | Grab a cold coconut water (₹30). |\n| **Day\u202f2** | **Morning** | **Scooter Rental** | Rental shop near hotel | ₹300 | 24‑hr scooter, 3\u202fkm/100\u202fkm. |\n| | **Morning** | **Explore North Goa** | Anjuna, Vagator | Free | Wander the flea markets, beach shacks. |\n| | **Mid‑day** | **Lunch** | Local shack | ₹120 | “Goan fish curry” with rice. |\n| | **Afternoon** | **Water‑Sports** | Calangute or Baga | ₹1\u202f000 | Parasailing + banana boat combo (budget). |\n| | **Late‑afternoon** | **Sunset at Chapora Fort** | Chapora Fort | Free | Great photo ops. |\n| | **Evening** | **Dinner** | Panjim (downtown) | ₹200 | Try “Prawn Curry” at a local restaurant. |\n| | **Night** | **Club/Bar** | Tito’s or Mambo’s | ₹300 (drink) | If you’re up for a bit of nightlife. |\n| **Day\u202f3** | **Morning** | **South Goa** | Palolem or Agonda | Free | Relaxing beaches, less crowded. |\n| | **Mid‑day** | **Lunch** | Beach shack | ₹120 | “Goan Fish Tacos” (₹120). |\n| | **Afternoon** | **Dudhsagar Falls** | (Optional day‑trip) | ₹1\u202f500 (bus + entry) | Book a local tour; includes lunch. |\n| | **Late‑afternoon** | **Return to Mumbai** | Train/Bus | ₹800 | Leave by 4\u202fpm to catch the evening train. |\n| | **Night** | **Arrival in Mumbai** | | | |\n\n---\n\n## Cost Breakdown (₹)\n\n| Category | Cost | Notes |\n|----------|------|-------|\n| **Transport (Mumbai‑Goa)** | ₹800 | Bus (cheapest) |\n| **Accommodation (2 nights)** | ₹1\u202f500 | Dorm room or budget guesthouse |\n| **Food (3 days)** | ₹2\u202f400 | 3 meals/day at ₹300–₹400 |\n| **Activities (Water‑sports, Fort entry)** | ₹1\u202f500 | Parasailing + entry fees |\n| **Scooter Rental** | ₹300 | 24‑hr |\n| **Miscellaneous (Souvenirs, extra drinks)** | ₹500 | Buffer |\n| **Total** | **₹7\u202f500** | **Leaves ₹7\u202f500 for flexibility** |\n\n> **Why we’re under budget?**  \n> - Staying in dorms/guesthouses keeps lodging cheap.  \n> - Eating at beach shacks or local thalis cuts food costs.  \n> - Most beaches are free; only the water‑sports and Dudhsagar trip cost extra.\n\n---\n\n## Packing Checklist\n\n| Item | Why |\n|------|-----|\n| Light, breathable clothing | Goa is hot & humid |\n| Swimwear & towel | Beach days |\n| Sunscreen (SPF\u202f50+) | Protect skin |\n| Hat & sunglasses | UV protection |\n| Flip‑flops & sandals | Beach & casual |\n| Light rain jacket | Monsoon season |\n| Small backpack | Carry snacks, water |\n| Power bank | Phone & camera |\n| Reusable water bottle | Stay hydrated |\n\n---\n\n## Safety & Tips\n\n| Tip | Explanation |\n|-----|-------------|\n| **Book train/bus tickets early** | Prices rise close to departure. |\n| **Stay in a well‑rated hostel** | Read recent reviews for safety. |\n| **Use licensed scooter rentals** | Verify insurance & helmet. |\n| **Avoid sharing water bott ...
# DEBUG Result: {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'proposed_plan': '## 3‑Day Mumbai‑to‑Goa Itinerary  \n**Budget:** ₹15\u202f000 (≈\u202f$200)  \n**Tone:** Fun, friendly, “just the right amount of adventure”  \n\n> **Tip:** Book everything at least 2–3\u202fweeks in advance to snag the best rates (especially trains/buses and hostels).  \n\n---\n\n| Day | Time | What to Do | Where | Cost | Notes |\n|-----|------|------------|-------|------|-------|\n| **Day\u202f1** | **Morning** | **Leave Mumbai** | Train/Bus (Mumbai‑Goa) | ₹800 (bus) or ₹1\u202f200 (passenger train) | If you’re a night‑owl, catch a late‑night train (≈\u202f10\u202fh) and arrive early in Goa. |\n| | **Afternoon** | **Check‑in & Lunch** | Budget guesthouse/hostel near Calangute | ₹1\u202f500 (2‑bedroom dorm) | Grab a local thali or a veggie wrap – around ₹150. |\n| | **Afternoon** | **Beach Time** | Calangute & Baga | Free | Sunset at Baga Beach is a must‑see. |\n| | **Evening** | **Dinner & Night Market** | Mapusa Night Market | ₹200 | Try the famous “Prawns with coconut milk” (≈\u202f₹150). |\n| | **Night** | **Relax / Light Walk** | Calangute | Free | Grab a cold coconut water (₹30). |\n| **Day\u202f2** | **Morning** | **Scooter Rental** | Rental shop near hotel | ₹300 | 24‑hr scooter, 3\u202fkm/100\u202fkm. |\n| | **Morning** | **Explore North Goa** | Anjuna, Vagator | Free | Wander the flea markets, beach shacks. |\n| | **Mid‑day** | **Lunch** | Local shack | ₹120 | “Goan fish curry” with rice. |\n| | **Afternoon** | **Water‑Sports** | Calangute or Baga | ₹1\u202f000 | Parasailing + banana boat combo (budget). |\n| | **Late‑afternoon** | **Sunset at Chapora Fort** | Chapora Fort | Free | Great photo ops. |\n| | **Evening** | **Dinner** | Panjim (downtown) | ₹200 | Try “Prawn Curry” at a local restaurant. |\n| | **Night** | **Club/Bar** | Tito’s or Mambo’s | ₹300 (drink) | If you’re up for a bit of nightlife. |\n| **Day\u202f3** | **Morning** | **South Goa** | Palolem or Agonda | Free | Relaxing beaches, less crowded. |\n| | **Mid‑day** | **Lunch** | Beach shack | ₹120 | “Goan Fish Tacos” (₹120). |\n| | **Afternoon** | **Dudhsagar Falls** | (Optional day‑trip) | ₹1\u202f500 (bus + entry) | Book a local tour; includes lunch. |\n| | **Late‑afternoon** | **Return to Mumbai** | Train/Bus | ₹800 | Leave by 4\u202fpm to catch the evening train. |\n| | **Night** | **Arrival in Mumbai** | | | |\n\n---\n\n## Cost Breakdown (₹)\n\n| Category | Cost | Notes |\n|----------|------|-------|\n| **Transport (Mumbai‑Goa)** | ₹800 | Bus (cheapest) |\n| **Accommodation (2 nights)** | ₹1\u202f500 | Dorm room or budget guesthouse |\n| **Food (3 days)** | ₹2\u202f400 | 3 meals/day at ₹300–₹400 |\n| **Activities (Water‑sports, Fort entry)** | ₹1\u202f500 | Parasailing + entry fees |\n| **Scooter Rental** | ₹300 | 24‑hr |\n| **Miscellaneous (Souvenirs, extra drinks)** | ₹500 | Buffer |\n| **Total** | **₹7\u202f500** | **Leaves ₹7\u202f500 for flexibility** |\n\n> **Why we’re under budget?**  \n> - Staying in dorms/guesthouses keeps lodging cheap.  \n> - Eating at beach shacks or local thalis cuts food costs.  \n> - Most beaches are free; only the water‑sports and Dudhsagar trip cost extra.\n\n---\n\n## Packing Checklist\n\n| Item | Why |\n|------|-----|\n| Light, breathable clothing | Goa is hot & humid |\n| Swimwear & towel | Beach days |\n| Sunscreen (SPF\u202f50+) | Protect skin |\n| Hat & sunglasses | UV protection |\n| Flip‑flops & sandals | Beach & casual |\n| Light rain jacket | Monsoon season |\n| Small backpack | Carry snacks, water |\n| Power bank | Phone & camera |\n| Reusable water bottle | Stay hydrated |\n\n---\n\n## Safety & Tips\n\n| Tip | Explanation |\n|-----|-------------|\n| **Book train/bus tickets early** | Prices rise close to departure. |\n| **Stay in a well‑rated hostel** | Read recent reviews for safety. |\n| **Use licensed scooter rentals** | Verify insurance & helmet. |\n| **Avoid sharing water bot ...
# DEBUG: Entering review_info with state {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'proposed_plan': '## 3‑Day Mumbai‑to‑Goa Itinerary  \n**Budget:** ₹15\u202f000 (≈\u202f$200)  \n**Tone:** Fun, friendly, “just the right amount of adventure”  \n\n> **Tip:** Book everything at least 2–3\u202fweeks in advance to snag the best rates (especially trains/buses and hostels).  \n\n---\n\n| Day | Time | What to Do | Where | Cost | Notes |\n|-----|------|------------|-------|------|-------|\n| **Day\u202f1** | **Morning** | **Leave Mumbai** | Train/Bus (Mumbai‑Goa) | ₹800 (bus) or ₹1\u202f200 (passenger train) | If you’re a night‑owl, catch a late‑night train (≈\u202f10\u202fh) and arrive early in Goa. |\n| | **Afternoon** | **Check‑in & Lunch** | Budget guesthouse/hostel near Calangute | ₹1\u202f500 (2‑bedroom dorm) | Grab a local thali or a veggie wrap – around ₹150. |\n| | **Afternoon** | **Beach Time** | Calangute & Baga | Free | Sunset at Baga Beach is a must‑see. |\n| | **Evening** | **Dinner & Night Market** | Mapusa Night Market | ₹200 | Try the famous “Prawns with coconut milk” (≈\u202f₹150). |\n| | **Night** | **Relax / Light Walk** | Calangute | Free | Grab a cold coconut water (₹30). |\n| **Day\u202f2** | **Morning** | **Scooter Rental** | Rental shop near hotel | ₹300 | 24‑hr scooter, 3\u202fkm/100\u202fkm. |\n| | **Morning** | **Explore North Goa** | Anjuna, Vagator | Free | Wander the flea markets, beach shacks. |\n| | **Mid‑day** | **Lunch** | Local shack | ₹120 | “Goan fish curry” with rice. |\n| | **Afternoon** | **Water‑Sports** | Calangute or Baga | ₹1\u202f000 | Parasailing + banana boat combo (budget). |\n| | **Late‑afternoon** | **Sunset at Chapora Fort** | Chapora Fort | Free | Great photo ops. |\n| | **Evening** | **Dinner** | Panjim (downtown) | ₹200 | Try “Prawn Curry” at a local restaurant. |\n| | **Night** | **Club/Bar** | Tito’s or Mambo’s | ₹300 (drink) | If you’re up for a bit of nightlife. |\n| **Day\u202f3** | **Morning** | **South Goa** | Palolem or Agonda | Free | Relaxing beaches, less crowded. |\n| | **Mid‑day** | **Lunch** | Beach shack | ₹120 | “Goan Fish Tacos” (₹120). |\n| | **Afternoon** | **Dudhsagar Falls** | (Optional day‑trip) | ₹1\u202f500 (bus + entry) | Book a local tour; includes lunch. |\n| | **Late‑afternoon** | **Return to Mumbai** | Train/Bus | ₹800 | Leave by 4\u202fpm to catch the evening train. |\n| | **Night** | **Arrival in Mumbai** | | | |\n\n---\n\n## Cost Breakdown (₹)\n\n| Category | Cost | Notes |\n|----------|------|-------|\n| **Transport (Mumbai‑Goa)** | ₹800 | Bus (cheapest) |\n| **Accommodation (2 nights)** | ₹1\u202f500 | Dorm room or budget guesthouse |\n| **Food (3 days)** | ₹2\u202f400 | 3 meals/day at ₹300–₹400 |\n| **Activities (Water‑sports, Fort entry)** | ₹1\u202f500 | Parasailing + entry fees |\n| **Scooter Rental** | ₹300 | 24‑hr |\n| **Miscellaneous (Souvenirs, extra drinks)** | ₹500 | Buffer |\n| **Total** | **₹7\u202f500** | **Leaves ₹7\u202f500 for flexibility** |\n\n> **Why we’re under budget?**  \n> - Staying in dorms/guesthouses keeps lodging cheap.  \n> - Eating at beach shacks or local thalis cuts food costs.  \n> - Most beaches are free; only the water‑sports and Dudhsagar trip cost extra.\n\n---\n\n## Packing Checklist\n\n| Item | Why |\n|------|-----|\n| Light, breathable clothing | Goa is hot & humid |\n| Swimwear & towel | Beach days |\n| Sunscreen (SPF\u202f50+) | Protect skin |\n| Hat & sunglasses | UV protection |\n| Flip‑flops & sandals | Beach & casual |\n| Light rain jacket | Monsoon season |\n| Small backpack | Carry snacks, water |\n| Power bank | Phone & camera |\n| Reusable water bottle | Stay hydrated |\n\n---\n\n## Safety & Tips\n\n| Tip | Explanation |\n|-----|-------------|\n| **Book train/bus tickets early** | Prices rise close to departure. |\n| **Stay in a well‑rated hostel** | Read recent reviews for safety. |\n| **Use licensed scooter rentals** | Verify insurance & helmet. |\n|  ...
# DEBUG: Got answer for review:
# Entering extract_change_field
# DEBUG: LLM slot change extraction: 'proceed'
# DEBUG: type of change_field: <class 'str'>
# DEBUG: LLM extracted in review_info: proceed
# DEBUG: In review_router with state {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'proposed_plan': '## 3‑Day Mumbai‑to‑Goa Itinerary  \n**Budget:** ₹15\u202f000 (≈\u202f$200)  \n**Tone:** Fun, friendly, “just the right amount of adventure”  \n\n> **Tip:** Book everything at least 2–3\u202fweeks in advance to snag the best rates (especially trains/buses and hostels).  \n\n---\n\n| Day | Time | What to Do | Where | Cost | Notes |\n|-----|------|------------|-------|------|-------|\n| **Day\u202f1** | **Morning** | **Leave Mumbai** | Train/Bus (Mumbai‑Goa) | ₹800 (bus) or ₹1\u202f200 (passenger train) | If you’re a night‑owl, catch a late‑night train (≈\u202f10\u202fh) and arrive early in Goa. |\n| | **Afternoon** | **Check‑in & Lunch** | Budget guesthouse/hostel near Calangute | ₹1\u202f500 (2‑bedroom dorm) | Grab a local thali or a veggie wrap – around ₹150. |\n| | **Afternoon** | **Beach Time** | Calangute & Baga | Free | Sunset at Baga Beach is a must‑see. |\n| | **Evening** | **Dinner & Night Market** | Mapusa Night Market | ₹200 | Try the famous “Prawns with coconut milk” (≈\u202f₹150). |\n| | **Night** | **Relax / Light Walk** | Calangute | Free | Grab a cold coconut water (₹30). |\n| **Day\u202f2** | **Morning** | **Scooter Rental** | Rental shop near hotel | ₹300 | 24‑hr scooter, 3\u202fkm/100\u202fkm. |\n| | **Morning** | **Explore North Goa** | Anjuna, Vagator | Free | Wander the flea markets, beach shacks. |\n| | **Mid‑day** | **Lunch** | Local shack | ₹120 | “Goan fish curry” with rice. |\n| | **Afternoon** | **Water‑Sports** | Calangute or Baga | ₹1\u202f000 | Parasailing + banana boat combo (budget). |\n| | **Late‑afternoon** | **Sunset at Chapora Fort** | Chapora Fort | Free | Great photo ops. |\n| | **Evening** | **Dinner** | Panjim (downtown) | ₹200 | Try “Prawn Curry” at a local restaurant. |\n| | **Night** | **Club/Bar** | Tito’s or Mambo’s | ₹300 (drink) | If you’re up for a bit of nightlife. |\n| **Day\u202f3** | **Morning** | **South Goa** | Palolem or Agonda | Free | Relaxing beaches, less crowded. |\n| | **Mid‑day** | **Lunch** | Beach shack | ₹120 | “Goan Fish Tacos” (₹120). |\n| | **Afternoon** | **Dudhsagar Falls** | (Optional day‑trip) | ₹1\u202f500 (bus + entry) | Book a local tour; includes lunch. |\n| | **Late‑afternoon** | **Return to Mumbai** | Train/Bus | ₹800 | Leave by 4\u202fpm to catch the evening train. |\n| | **Night** | **Arrival in Mumbai** | | | |\n\n---\n\n## Cost Breakdown (₹)\n\n| Category | Cost | Notes |\n|----------|------|-------|\n| **Transport (Mumbai‑Goa)** | ₹800 | Bus (cheapest) |\n| **Accommodation (2 nights)** | ₹1\u202f500 | Dorm room or budget guesthouse |\n| **Food (3 days)** | ₹2\u202f400 | 3 meals/day at ₹300–₹400 |\n| **Activities (Water‑sports, Fort entry)** | ₹1\u202f500 | Parasailing + entry fees |\n| **Scooter Rental** | ₹300 | 24‑hr |\n| **Miscellaneous (Souvenirs, extra drinks)** | ₹500 | Buffer |\n| **Total** | **₹7\u202f500** | **Leaves ₹7\u202f500 for flexibility** |\n\n> **Why we’re under budget?**  \n> - Staying in dorms/guesthouses keeps lodging cheap.  \n> - Eating at beach shacks or local thalis cuts food costs.  \n> - Most beaches are free; only the water‑sports and Dudhsagar trip cost extra.\n\n---\n\n## Packing Checklist\n\n| Item | Why |\n|------|-----|\n| Light, breathable clothing | Goa is hot & humid |\n| Swimwear & towel | Beach days |\n| Sunscreen (SPF\u202f50+) | Protect skin |\n| Hat & sunglasses | UV protection |\n| Flip‑flops & sandals | Beach & casual |\n| Light rain jacket | Monsoon season |\n| Small backpack | Carry snacks, water |\n| Power bank | Phone & camera |\n| Reusable water bottle | Stay hydrated |\n\n---\n\n## Safety & Tips\n\n| Tip | Explanation |\n|-----|-------------|\n| **Book train/bus tickets early** | Prices rise close to departure. |\n| **Stay in a well‑rated hostel** | Read recent reviews for safety. |\n| **Use licensed scooter rentals** | Verify insurance & helmet. |\n| **Av ...
# DEBUG: In review_router, missing fields: []
# DEBUG: Entering plan_trip with state {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'proposed_plan': '## 3‑Day Mumbai‑to‑Goa Itinerary  \n**Budget:** ₹15\u202f000 (≈\u202f$200)  \n**Tone:** Fun, friendly, “just the right amount of adventure”  \n\n> **Tip:** Book everything at least 2–3\u202fweeks in advance to snag the best rates (especially trains/buses and hostels).  \n\n---\n\n| Day | Time | What to Do | Where | Cost | Notes |\n|-----|------|------------|-------|------|-------|\n| **Day\u202f1** | **Morning** | **Leave Mumbai** | Train/Bus (Mumbai‑Goa) | ₹800 (bus) or ₹1\u202f200 (passenger train) | If you’re a night‑owl, catch a late‑night train (≈\u202f10\u202fh) and arrive early in Goa. |\n| | **Afternoon** | **Check‑in & Lunch** | Budget guesthouse/hostel near Calangute | ₹1\u202f500 (2‑bedroom dorm) | Grab a local thali or a veggie wrap – around ₹150. |\n| | **Afternoon** | **Beach Time** | Calangute & Baga | Free | Sunset at Baga Beach is a must‑see. |\n| | **Evening** | **Dinner & Night Market** | Mapusa Night Market | ₹200 | Try the famous “Prawns with coconut milk” (≈\u202f₹150). |\n| | **Night** | **Relax / Light Walk** | Calangute | Free | Grab a cold coconut water (₹30). |\n| **Day\u202f2** | **Morning** | **Scooter Rental** | Rental shop near hotel | ₹300 | 24‑hr scooter, 3\u202fkm/100\u202fkm. |\n| | **Morning** | **Explore North Goa** | Anjuna, Vagator | Free | Wander the flea markets, beach shacks. |\n| | **Mid‑day** | **Lunch** | Local shack | ₹120 | “Goan fish curry” with rice. |\n| | **Afternoon** | **Water‑Sports** | Calangute or Baga | ₹1\u202f000 | Parasailing + banana boat combo (budget). |\n| | **Late‑afternoon** | **Sunset at Chapora Fort** | Chapora Fort | Free | Great photo ops. |\n| | **Evening** | **Dinner** | Panjim (downtown) | ₹200 | Try “Prawn Curry” at a local restaurant. |\n| | **Night** | **Club/Bar** | Tito’s or Mambo’s | ₹300 (drink) | If you’re up for a bit of nightlife. |\n| **Day\u202f3** | **Morning** | **South Goa** | Palolem or Agonda | Free | Relaxing beaches, less crowded. |\n| | **Mid‑day** | **Lunch** | Beach shack | ₹120 | “Goan Fish Tacos” (₹120). |\n| | **Afternoon** | **Dudhsagar Falls** | (Optional day‑trip) | ₹1\u202f500 (bus + entry) | Book a local tour; includes lunch. |\n| | **Late‑afternoon** | **Return to Mumbai** | Train/Bus | ₹800 | Leave by 4\u202fpm to catch the evening train. |\n| | **Night** | **Arrival in Mumbai** | | | |\n\n---\n\n## Cost Breakdown (₹)\n\n| Category | Cost | Notes |\n|----------|------|-------|\n| **Transport (Mumbai‑Goa)** | ₹800 | Bus (cheapest) |\n| **Accommodation (2 nights)** | ₹1\u202f500 | Dorm room or budget guesthouse |\n| **Food (3 days)** | ₹2\u202f400 | 3 meals/day at ₹300–₹400 |\n| **Activities (Water‑sports, Fort entry)** | ₹1\u202f500 | Parasailing + entry fees |\n| **Scooter Rental** | ₹300 | 24‑hr |\n| **Miscellaneous (Souvenirs, extra drinks)** | ₹500 | Buffer |\n| **Total** | **₹7\u202f500** | **Leaves ₹7\u202f500 for flexibility** |\n\n> **Why we’re under budget?**  \n> - Staying in dorms/guesthouses keeps lodging cheap.  \n> - Eating at beach shacks or local thalis cuts food costs.  \n> - Most beaches are free; only the water‑sports and Dudhsagar trip cost extra.\n\n---\n\n## Packing Checklist\n\n| Item | Why |\n|------|-----|\n| Light, breathable clothing | Goa is hot & humid |\n| Swimwear & towel | Beach days |\n| Sunscreen (SPF\u202f50+) | Protect skin |\n| Hat & sunglasses | UV protection |\n| Flip‑flops & sandals | Beach & casual |\n| Light rain jacket | Monsoon season |\n| Small backpack | Carry snacks, water |\n| Power bank | Phone & camera |\n| Reusable water bottle | Stay hydrated |\n\n---\n\n## Safety & Tips\n\n| Tip | Explanation |\n|-----|-------------|\n| **Book train/bus tickets early** | Prices rise close to departure. |\n| **Stay in a well‑rated hostel** | Read recent reviews for safety. |\n| **Use licensed scooter rentals** | Verify insurance & helmet. |\n| ** ...
#
# Your itinerary:
# **3‑Day, 15 000 ₹ Friendly & Fun Trip: Mumbai ➜ Goa ➜ Mumbai**
#
# > *All prices are approximate (₹) and can vary by season.
# >  The plan assumes you’ll stay in a budget hostel/guesthouse, use public transport, and eat at local eateries.*
#
# | Day | Time | Activity | Notes | Approx. Cost |
# |-----|------|----------|-------|--------------|
# | **Day 1** | 07:00‑10:00 | **Mumbai ➜ Goa (Train)** | Book a 3rd‑class sleeper on the *Mumbai‑Goa Express* (train 12932). 3‑hour ride, cheap fare (~₹300). | ₹300 |
# | | 10:30‑12:00 | **Check‑in & Refresh** | Hostels: Zostel (₹1,200/night) or budget guesthouse (₹1,500). | ₹1,200 |
# | | 12:30‑13:30 | **Lunch** | Local Goan thali (~₹200). | ₹200 |
# | | 14:00‑18:00 | **Explore North Goa Beaches** | Baga, Calangute, Anjuna – stroll, sun‑bathing, free beach access. | ₹0 |
# | | 18:30‑20:00 | **Dinner** | Beach shack (Prawns, fish) (~₹250). | ₹250 |
# | | 20:30‑22:30 | **Nightlife** | Free beach party at Baga (music, drinks – optional). | ₹0–₹100 (if you buy a drink) |
# | | 23:00 | **Return to Hostel** | | |
#
# **Day 1 Total**: ₹1,850
#
# ---
#
# | **Day 2** |  |  |  |  |
# |-----------|---|---|---|---|
# | 07:00‑08:00 | **Breakfast** | Hostel buffet or local bakery (~₹100). | ₹100 |
# | 08:30‑10:30 | **Water Sports** | Kite surfing or banana boat at Anjuna (₹400). | ₹400 |
# | 11:00‑13:00 | **Lunch** | Street food (vada pav, pav bhaji) (~₹150). | ₹150 |
# | 13:30‑17:30 | **Dudhsagar Falls Day‑Trip** | Book a local tour (₹700) including transport and lunch. | ₹700 |
# | 18:00‑19:30 | **Return & Freshen Up** | | |
# | 20:00‑21:30 | **Dinner** | Goan pizza or seafood (~₹300). | ₹300 |
# | 22:00‑23:30 | **Evening Stroll** | Mapusa Market (if on the way back) – free. | ₹0 |
#
# **Day 2 Total**: ₹1,650
#
# ---
#
# | **Day 3** |  |  |  |  |
# |-----------|---|---|---|---|
# | 07:30‑08:30 | **Breakfast** | Hostel or local café (~₹120). | ₹120 |
# | 09:00‑11:30 | **Old Goa & Churches** | UNESCO sites (Basilica of Bom Jesus, Se Cathedral) – free entry. | ₹0 |
# | 12:00‑13:00 | **Lunch** | Local Goan café (~₹200). | ₹200 |
# | 13:30‑15:30 | **South Goa Beach** | Colva or Palolem – relaxed vibe, free. | ₹0 |
# | 16:00‑18:00 | **Souvenir Shopping** | Local market (bracelets, handicrafts) – set a budget of ₹300. | ₹300 |
# | 18:30‑19:00 | **Dinner** | Quick bite (~₹150). | ₹150 |
# | 19:30‑21:30 | **Bus/Train to Mumbai** | 4th‑class sleeper/Volvo bus (~₹300). | ₹300 |
# | 22:30 | **Arrive Mumbai** | | |
#
# **Day 3 Total**: ₹1,020
#
# ---
#
# ## Budget Summary
#
# | Category | Cost (₹) |
# |----------|----------|
# | Train (Mumbai‑Goa) | 300 |
# | Train (Goa‑Mumbai) | 300 |
# | Accommodation (3 nights) | 3 600 |
# | Food & Drinks | 2 500 |
# | Activities (water sports, Dudhsagar tour) | 1 400 |
# | Local Transport (auto, bus, scooter) | 800 |
# | Souvenirs | 300 |
# | **Total** | **≈ 11 800** |
#
# **Remaining cushion** (~₹3 200) → extra drinks, a night‑club entry, or a short scooter rental.
#
# ---
#
# ## Quick Tips
#
# | Tip | Why It Helps |
# |-----|--------------|
# | **Book trains early** | Fares rise closer to departure; you can snag a cheaper 3rd‑class berth. |
# | **Stay in a hostel** | Hostels offer free Wi‑Fi, common kitchen, and a chance to meet fellow travelers. |
# | **Use local buses** | Buses between major towns cost ~₹30–₹50; great for budget. |
# | **Pack light** | Avoid baggage fees on trains/buses and keep your luggage manageable. |
# | **Try local street food** | Authentic and inexpensive; just pick stalls that look busy (good sign). |
# | **Carry cash** | Many small shops and beach shacks accept only cash. |
# | **Plan free activities** | Beaches, churches, markets are free; they’re the best way to soak in Goa. |
#
# ---
#
# ## Suggested Packing List
#
# | Item | Why |
# |------|-----|
# | Light cotton clothing | Goa is hot & humid. |
# | Swimwear | Free beach access. |
# | Sunscreen (SPF 50+) | Protect from strong sun. |
# | Comfortable sandals & walking shoes | For beach & temple visits. |
# | Small backpack | Keep essentials handy. |
# | Reusable water bottle | Stay hydrated, eco‑friendly. |
# | Power bank | Keep your phone charged. |
#
# ---
#
# ### Final Thought
#
# With a bit of planning, you can enjoy a memorable 3‑day Goa adventure while keeping the cost comfortably under your ₹15 000 budget. Have a fantastic trip—enjoy the beaches, the
#
# ...
# DEBUG: Entering ask_starting_point with state
# DEBUG: Entering ask_destination with state
# DEBUG: Entering ask_budget with state
# DEBUG: Entering ask_duration with state
# DEBUG: Entering review_info with state {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'proposed_plan': '**3‑Day, 15\u202f000\u202f₹ Friendly & Fun Trip: Mumbai ➜ Goa ➜ Mumbai**\n\n> *All prices are approximate (₹) and can vary by season.  \n>  The plan assumes you’ll stay in a budget hostel/guesthouse, use public transport, and eat at local eateries.*\n\n| Day | Time | Activity | Notes | Approx. Cost |\n|-----|------|----------|-------|--------------|\n| **Day\u202f1** | 07:00‑10:00 | **Mumbai ➜ Goa (Train)** | Book a 3rd‑class sleeper on the *Mumbai‑Goa Express* (train 12932). 3‑hour ride, cheap fare (~₹300). | ₹300 |\n| | 10:30‑12:00 | **Check‑in & Refresh** | Hostels: Zostel (₹1,200/night) or budget guesthouse (₹1,500). | ₹1,200 |\n| | 12:30‑13:30 | **Lunch** | Local Goan thali (~₹200). | ₹200 |\n| | 14:00‑18:00 | **Explore North Goa Beaches** | Baga, Calangute, Anjuna – stroll, sun‑bathing, free beach access. | ₹0 |\n| | 18:30‑20:00 | **Dinner** | Beach shack (Prawns, fish) (~₹250). | ₹250 |\n| | 20:30‑22:30 | **Nightlife** | Free beach party at Baga (music, drinks – optional). | ₹0–₹100 (if you buy a drink) |\n| | 23:00 | **Return to Hostel** | | |\n\n**Day\u202f1 Total**: ₹1,850\n\n---\n\n| **Day\u202f2** |  |  |  |  |\n|-----------|---|---|---|---|\n| 07:00‑08:00 | **Breakfast** | Hostel buffet or local bakery (~₹100). | ₹100 |\n| 08:30‑10:30 | **Water Sports** | Kite surfing or banana boat at Anjuna (₹400). | ₹400 |\n| 11:00‑13:00 | **Lunch** | Street food (vada pav, pav bhaji) (~₹150). | ₹150 |\n| 13:30‑17:30 | **Dudhsagar Falls Day‑Trip** | Book a local tour (₹700) including transport and lunch. | ₹700 |\n| 18:00‑19:30 | **Return & Freshen Up** | | |\n| 20:00‑21:30 | **Dinner** | Goan pizza or seafood (~₹300). | ₹300 |\n| 22:00‑23:30 | **Evening Stroll** | Mapusa Market (if on the way back) – free. | ₹0 |\n\n**Day\u202f2 Total**: ₹1,650\n\n---\n\n| **Day\u202f3** |  |  |  |  |\n|-----------|---|---|---|---|\n| 07:30‑08:30 | **Breakfast** | Hostel or local café (~₹120). | ₹120 |\n| 09:00‑11:30 | **Old Goa & Churches** | UNESCO sites (Basilica of Bom Jesus, Se Cathedral) – free entry. | ₹0 |\n| 12:00‑13:00 | **Lunch** | Local Goan café (~₹200). | ₹200 |\n| 13:30‑15:30 | **South Goa Beach** | Colva or Palolem – relaxed vibe, free. | ₹0 |\n| 16:00‑18:00 | **Souvenir Shopping** | Local market (bracelets, handicrafts) – set a budget of ₹300. | ₹300 |\n| 18:30‑19:00 | **Dinner** | Quick bite (~₹150). | ₹150 |\n| 19:30‑21:30 | **Bus/Train to Mumbai** | 4th‑class sleeper/Volvo bus (~₹300). | ₹300 |\n| 22:30 | **Arrive Mumbai** | | |\n\n**Day\u202f3 Total**: ₹1,020\n\n---\n\n## Budget Summary\n\n| Category | Cost (₹) |\n|----------|----------|\n| Train (Mumbai‑Goa) | 300 |\n| Train (Goa‑Mumbai) | 300 |\n| Accommodation (3 nights) | 3\u202f600 |\n| Food & Drinks | 2\u202f500 |\n| Activities (water sports, Dudhsagar tour) | 1\u202f400 |\n| Local Transport (auto, bus, scooter) | 800 |\n| Souvenirs | 300 |\n| **Total** | **≈\u202f11\u202f800** |\n\n**Remaining cushion** (~₹3\u202f200) → extra drinks, a night‑club entry, or a short scooter rental.\n\n---\n\n## Quick Tips\n\n| Tip | Why It Helps |\n|-----|--------------|\n| **Book trains early** | Fares rise closer to departure; you can snag a cheaper 3rd‑class berth. |\n| **Stay in a hostel** | Hostels offer free Wi‑Fi, common kitchen, and a chance to meet fellow travelers. |\n| **Use local buses** | Buses between major towns cost ~₹30–₹50; great for budget. |\n| **Pack light** | Avoid baggage fees on trains/buses and keep your luggage manageable. |\n| **Try local street food** | Authentic and inexpensive; just pick stalls that look busy (good sign). |\n| **Carry cash** | Many small shops and beach shacks accept only cash. |\n| **Plan free activities** | Beaches, churches, markets are free; they’re the best way to soak in Goa. |\n\n---\n\n## Suggested Packing List\n\n| Item | Why |\n|------|-----|\n| Light cotton clothing | Goa is hot &  ...
# DEBUG State: {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'proposed_plan': '**3‑Day, 15\u202f000\u202f₹ Friendly & Fun Trip: Mumbai ➜ Goa ➜ Mumbai**\n\n> *All prices are approximate (₹) and can vary by season.  \n>  The plan assumes you’ll stay in a budget hostel/guesthouse, use public transport, and eat at local eateries.*\n\n| Day | Time | Activity | Notes | Approx. Cost |\n|-----|------|----------|-------|--------------|\n| **Day\u202f1** | 07:00‑10:00 | **Mumbai ➜ Goa (Train)** | Book a 3rd‑class sleeper on the *Mumbai‑Goa Express* (train 12932). 3‑hour ride, cheap fare (~₹300). | ₹300 |\n| | 10:30‑12:00 | **Check‑in & Refresh** | Hostels: Zostel (₹1,200/night) or budget guesthouse (₹1,500). | ₹1,200 |\n| | 12:30‑13:30 | **Lunch** | Local Goan thali (~₹200). | ₹200 |\n| | 14:00‑18:00 | **Explore North Goa Beaches** | Baga, Calangute, Anjuna – stroll, sun‑bathing, free beach access. | ₹0 |\n| | 18:30‑20:00 | **Dinner** | Beach shack (Prawns, fish) (~₹250). | ₹250 |\n| | 20:30‑22:30 | **Nightlife** | Free beach party at Baga (music, drinks – optional). | ₹0–₹100 (if you buy a drink) |\n| | 23:00 | **Return to Hostel** | | |\n\n**Day\u202f1 Total**: ₹1,850\n\n---\n\n| **Day\u202f2** |  |  |  |  |\n|-----------|---|---|---|---|\n| 07:00‑08:00 | **Breakfast** | Hostel buffet or local bakery (~₹100). | ₹100 |\n| 08:30‑10:30 | **Water Sports** | Kite surfing or banana boat at Anjuna (₹400). | ₹400 |\n| 11:00‑13:00 | **Lunch** | Street food (vada pav, pav bhaji) (~₹150). | ₹150 |\n| 13:30‑17:30 | **Dudhsagar Falls Day‑Trip** | Book a local tour (₹700) including transport and lunch. | ₹700 |\n| 18:00‑19:30 | **Return & Freshen Up** | | |\n| 20:00‑21:30 | **Dinner** | Goan pizza or seafood (~₹300). | ₹300 |\n| 22:00‑23:30 | **Evening Stroll** | Mapusa Market (if on the way back) – free. | ₹0 |\n\n**Day\u202f2 Total**: ₹1,650\n\n---\n\n| **Day\u202f3** |  |  |  |  |\n|-----------|---|---|---|---|\n| 07:30‑08:30 | **Breakfast** | Hostel or local café (~₹120). | ₹120 |\n| 09:00‑11:30 | **Old Goa & Churches** | UNESCO sites (Basilica of Bom Jesus, Se Cathedral) – free entry. | ₹0 |\n| 12:00‑13:00 | **Lunch** | Local Goan café (~₹200). | ₹200 |\n| 13:30‑15:30 | **South Goa Beach** | Colva or Palolem – relaxed vibe, free. | ₹0 |\n| 16:00‑18:00 | **Souvenir Shopping** | Local market (bracelets, handicrafts) – set a budget of ₹300. | ₹300 |\n| 18:30‑19:00 | **Dinner** | Quick bite (~₹150). | ₹150 |\n| 19:30‑21:30 | **Bus/Train to Mumbai** | 4th‑class sleeper/Volvo bus (~₹300). | ₹300 |\n| 22:30 | **Arrive Mumbai** | | |\n\n**Day\u202f3 Total**: ₹1,020\n\n---\n\n## Budget Summary\n\n| Category | Cost (₹) |\n|----------|----------|\n| Train (Mumbai‑Goa) | 300 |\n| Train (Goa‑Mumbai) | 300 |\n| Accommodation (3 nights) | 3\u202f600 |\n| Food & Drinks | 2\u202f500 |\n| Activities (water sports, Dudhsagar tour) | 1\u202f400 |\n| Local Transport (auto, bus, scooter) | 800 |\n| Souvenirs | 300 |\n| **Total** | **≈\u202f11\u202f800** |\n\n**Remaining cushion** (~₹3\u202f200) → extra drinks, a night‑club entry, or a short scooter rental.\n\n---\n\n## Quick Tips\n\n| Tip | Why It Helps |\n|-----|--------------|\n| **Book trains early** | Fares rise closer to departure; you can snag a cheaper 3rd‑class berth. |\n| **Stay in a hostel** | Hostels offer free Wi‑Fi, common kitchen, and a chance to meet fellow travelers. |\n| **Use local buses** | Buses between major towns cost ~₹30–₹50; great for budget. |\n| **Pack light** | Avoid baggage fees on trains/buses and keep your luggage manageable. |\n| **Try local street food** | Authentic and inexpensive; just pick stalls that look busy (good sign). |\n| **Carry cash** | Many small shops and beach shacks accept only cash. |\n| **Plan free activities** | Beaches, churches, markets are free; they’re the best way to soak in Goa. |\n\n---\n\n## Suggested Packing List\n\n| Item | Why |\n|------|-----|\n| Light cotton clothing | Goa is hot & humid. |\n| Swimwear | Fre ...
# DEBUG Result: {'starting_point': 'mumbai', 'destination': 'goa', 'budget': '15000', 'duration': '3 days', 'proposed_plan': '**3‑Day, 15\u202f000\u202f₹ Friendly & Fun Trip: Mumbai ➜ Goa ➜ Mumbai**\n\n> *All prices are approximate (₹) and can vary by season.  \n>  The plan assumes you’ll stay in a budget hostel/guesthouse, use public transport, and eat at local eateries.*\n\n| Day | Time | Activity | Notes | Approx. Cost |\n|-----|------|----------|-------|--------------|\n| **Day\u202f1** | 07:00‑10:00 | **Mumbai ➜ Goa (Train)** | Book a 3rd‑class sleeper on the *Mumbai‑Goa Express* (train 12932). 3‑hour ride, cheap fare (~₹300). | ₹300 |\n| | 10:30‑12:00 | **Check‑in & Refresh** | Hostels: Zostel (₹1,200/night) or budget guesthouse (₹1,500). | ₹1,200 |\n| | 12:30‑13:30 | **Lunch** | Local Goan thali (~₹200). | ₹200 |\n| | 14:00‑18:00 | **Explore North Goa Beaches** | Baga, Calangute, Anjuna – stroll, sun‑bathing, free beach access. | ₹0 |\n| | 18:30‑20:00 | **Dinner** | Beach shack (Prawns, fish) (~₹250). | ₹250 |\n| | 20:30‑22:30 | **Nightlife** | Free beach party at Baga (music, drinks – optional). | ₹0–₹100 (if you buy a drink) |\n| | 23:00 | **Return to Hostel** | | |\n\n**Day\u202f1 Total**: ₹1,850\n\n---\n\n| **Day\u202f2** |  |  |  |  |\n|-----------|---|---|---|---|\n| 07:00‑08:00 | **Breakfast** | Hostel buffet or local bakery (~₹100). | ₹100 |\n| 08:30‑10:30 | **Water Sports** | Kite surfing or banana boat at Anjuna (₹400). | ₹400 |\n| 11:00‑13:00 | **Lunch** | Street food (vada pav, pav bhaji) (~₹150). | ₹150 |\n| 13:30‑17:30 | **Dudhsagar Falls Day‑Trip** | Book a local tour (₹700) including transport and lunch. | ₹700 |\n| 18:00‑19:30 | **Return & Freshen Up** | | |\n| 20:00‑21:30 | **Dinner** | Goan pizza or seafood (~₹300). | ₹300 |\n| 22:00‑23:30 | **Evening Stroll** | Mapusa Market (if on the way back) – free. | ₹0 |\n\n**Day\u202f2 Total**: ₹1,650\n\n---\n\n| **Day\u202f3** |  |  |  |  |\n|-----------|---|---|---|---|\n| 07:30‑08:30 | **Breakfast** | Hostel or local café (~₹120). | ₹120 |\n| 09:00‑11:30 | **Old Goa & Churches** | UNESCO sites (Basilica of Bom Jesus, Se Cathedral) – free entry. | ₹0 |\n| 12:00‑13:00 | **Lunch** | Local Goan café (~₹200). | ₹200 |\n| 13:30‑15:30 | **South Goa Beach** | Colva or Palolem – relaxed vibe, free. | ₹0 |\n| 16:00‑18:00 | **Souvenir Shopping** | Local market (bracelets, handicrafts) – set a budget of ₹300. | ₹300 |\n| 18:30‑19:00 | **Dinner** | Quick bite (~₹150). | ₹150 |\n| 19:30‑21:30 | **Bus/Train to Mumbai** | 4th‑class sleeper/Volvo bus (~₹300). | ₹300 |\n| 22:30 | **Arrive Mumbai** | | |\n\n**Day\u202f3 Total**: ₹1,020\n\n---\n\n## Budget Summary\n\n| Category | Cost (₹) |\n|----------|----------|\n| Train (Mumbai‑Goa) | 300 |\n| Train (Goa‑Mumbai) | 300 |\n| Accommodation (3 nights) | 3\u202f600 |\n| Food & Drinks | 2\u202f500 |\n| Activities (water sports, Dudhsagar tour) | 1\u202f400 |\n| Local Transport (auto, bus, scooter) | 800 |\n| Souvenirs | 300 |\n| **Total** | **≈\u202f11\u202f800** |\n\n**Remaining cushion** (~₹3\u202f200) → extra drinks, a night‑club entry, or a short scooter rental.\n\n---\n\n## Quick Tips\n\n| Tip | Why It Helps |\n|-----|--------------|\n| **Book trains early** | Fares rise closer to departure; you can snag a cheaper 3rd‑class berth. |\n| **Stay in a hostel** | Hostels offer free Wi‑Fi, common kitchen, and a chance to meet fellow travelers. |\n| **Use local buses** | Buses between major towns cost ~₹30–₹50; great for budget. |\n| **Pack light** | Avoid baggage fees on trains/buses and keep your luggage manageable. |\n| **Try local street food** | Authentic and inexpensive; just pick stalls that look busy (good sign). |\n| **Carry cash** | Many small shops and beach shacks accept only cash. |\n| **Plan free activities** | Beaches, churches, markets are free; they’re the best way to soak in Goa. |\n\n---\n\n## Suggested Packing List\n\n| Item | Why |\n|------|-----|\n| Light cotton clothing | Goa is hot & humid. |\n| Swimwear | Fr ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 17
#      15 if "__interrupt__" in result:
#      16     prompt = result["__interrupt__"][0].value
# ---> 17     user_input = input(prompt + " ")
#      18     state = workflow.invoke(Command(resume=user_input), config)
#      19     continue
#
# File c:\Users\smm931389\Desktop\RAG_patterns\.venv\Lib\site-packages\ipykernel\kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File c:\Users\smm931389\Desktop\RAG_patterns\.venv\Lib\site-packages\ipykernel\kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
#    1318     # re-raise KeyboardInterrupt, to truncate traceback
#    1319     msg = "Interrupted by user"
# -> 1320     raise KeyboardInterrupt(msg) from None
#    1321 except Exception:
#    1322     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## 2nd attempt

# %%
from typing import TypedDict, Optional
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import MemorySaver
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from langgraph.types import interrupt, Command
import uuid
import os

class TripState(TypedDict):
    starting_point: Optional[str]
    destination: Optional[str]
    budget: Optional[str]
    duration: Optional[str]
    proposed_plan: Optional[str]
    satisfied_with_plan: Optional[bool]
    done: Optional[bool]
    selected_flight: Optional[str]
    flight_source: Optional[str]
    flight_destination: Optional[str]
    flight_date: Optional[str]
    return_trip: Optional[bool]
    available_flights: Optional[list]

# %%
def get_groq_llm() -> ChatOpenAI:
    return ChatOpenAI(
        model="openai/gpt-oss-20b",
        base_url="https://api.groq.com/openai/v1",
        api_key=os.getenv("GROQ_API_KEY"),
        temperature=0.7,
        max_tokens=2000
    )

llm = get_groq_llm()
FIELDS = ["starting_point", "destination", "budget", "duration"]
FIELD_QS = {
    "starting_point": "Ask the user for their trip starting location in a friendly way.",
    "destination": "Ask the user where they'd like to travel, naturally.",
    "budget": "Ask the user what budget they'd like to set for the trip, friendly and casual.",
    "duration": "Ask, in a conversational style, how many days they want their trip to last."
}

def generate_slot_question(slot_name):
    print("DEBUG: Entering generate_slot_question()")
    prompt = FIELD_QS[slot_name]
    response  = llm.invoke(prompt)
    print(f"DEBUG: Generated question for '{slot_name}': {response.content}")
    return response.content

def extract_slot_value(slot_name, user_input):
    print("DEBUG: Entering extract_slot_value()")
    prompt = (
        f"You are a smart assistant filling out a travel form.\n"
        f"The user was asked to specify their '{slot_name.replace('_', ' ')}'.\n"
        f"User replied: \"{user_input}\"\n"
        f"Extract and reply with ONLY the value for '{slot_name}'. If no clear value is found, reply 'None'."
    )
    response = llm.invoke(prompt)
    if str(response.content).lower() == "none":
        response = None
    print(f"DEBUG: Extracted value for {slot_name}: '{response.content}'")
    return response.content

def extract_change_field(user_input: str) -> Optional[str]:
    """
    Detect which trip field (if any) the user wants to change, or if they want to proceed.
    Uses LLM for fuzzy detection, but is tolerant of natural human responses.
    """
    user_text = user_input.strip().lower()

    # --- Fast direct checks (no LLM call for simple confirmations) ---
    if any(word in user_text for word in ["proceed", "ok", "okay", "yes", "continue", "done", "confirm", "next", "go ahead", "move on"]):
        print("DEBUG: Direct 'proceed' detected without LLM.")
        return "proceed"

    # --- LLM fallback for detecting slot-change intent ---
    prompt = (
        "Decide which of these trip fields (if any) the user wants to update: "
        "starting_point, destination, budget, duration.\n"
        f"User said: \"{user_input}\"\n"
        "Reply ONLY with one of these: starting_point, destination, budget, duration, or 'proceed' if the user seems to approve or confirm."
    )

    try:
        result = llm.invoke(prompt)
    except Exception as e:
        print(f"DEBUG: extract_change_field LLM error: {e}")
        return None

    print(f"DEBUG: LLM slot change extraction: '{result.content}'")

    # --- Interpret LLM output robustly ---
    for f in FIELDS:
        if f in result.content:
            return f
    if any(word in result.content for word in ["proceed", "ok", "okay", "yes", "continue", "done", "confirm", "next"]):
        return "proceed"

    return None


def ask_starting_point(state: TripState) -> TripState:
    print("DEBUG: Entering ask_starting_point with state")
    if not state.get("starting_point"):
        q = generate_slot_question("starting_point")
        user_input = interrupt(q)
        value = extract_slot_value("starting_point", user_input)
        state["starting_point"] = value
    return state

def ask_destination(state: TripState) -> TripState:
    print("DEBUG: Entering ask_destination with state")
    if not state.get("destination"):
        q = generate_slot_question("destination")
        user_input = interrupt(q)
        value = extract_slot_value("destination", user_input)
        state["destination"] = value
    return state

def ask_budget(state: TripState) -> TripState:
    print("DEBUG: Entering ask_budget with state")
    if not state.get("budget"):
        q = generate_slot_question("budget")
        user_input = interrupt(q)
        value = extract_slot_value("budget", user_input)
        state["budget"] = value
    return state

def ask_duration(state: TripState) -> TripState:
    print("DEBUG: Entering ask_duration with state")
    if not state.get("duration"):
        q = generate_slot_question("duration")
        user_input = interrupt(q)
        value = extract_slot_value("duration", user_input)
        state["duration"] = value
    return state

def review_info(state: TripState) -> TripState:
    """
    Present current trip details, let user confirm or specify changes.
    """
    print("DEBUG: Entering review_info with state", state)

    summary = (
        f"Please review your trip details:\n"
        f"- Starting point: {state['starting_point']}\n"
        f"- Destination: {state['destination']}\n"
        f"- Budget: {state['budget']}\n"
        f"- Duration: {state['duration']}\n"
        "Reply 'proceed' to confirm, or say naturally what you'd like to change."
    )

    user_input = interrupt(summary)
    user_text = user_input.strip().lower()

    # --- Direct confirmation bypass (no LLM needed) ---
    if any(x in user_text for x in ["proceed", "ok", "okay", "yes", "continue", "done", "confirm", "next", "go ahead"]):
        print("DEBUG: Direct confirmation detected in review_info.")
        return state

    # --- Otherwise, let LLM detect if user mentioned a specific field to change ---
    change_field = extract_change_field(user_input)
    print(f"DEBUG: type of change_field: {type(change_field)}")
    print(f"DEBUG: LLM extracted in review_info: {change_field}")

    if change_field == "proceed":
        print("DEBUG: LLM confirmed proceed.")
        return state
    elif change_field in FIELDS:
        print(f"DEBUG: LLM detected change request for field '{change_field}', resetting it.")
        state[change_field] = None
        state['satisfied_with_plan'] = None
        return state
    else:
        print("DEBUG: Could not interpret response, re-asking review.")
        # Prevent infinite recursion — only re-ask once
        reask = interrupt("Sorry, I didn’t catch that. Would you like to proceed or change something?")
        if any(x in reask.lower() for x in ["proceed", "ok", "yes", "continue"]):
            return state
        return review_info(state)


def review_router(state: TripState):
    print("DEBUG: In review_router with state", state)
    missing = [fld for fld in FIELDS if not state.get(fld)]
    print(f"DEBUG: In review_router, missing fields: {missing}")
    if len(missing) > 0:
        return "review_info"
    return "plan_trip"

def plan_trip(state: TripState) -> TripState:
    print("DEBUG: Entering plan_trip with state", state)
    state['satisfied_with_plan'] = None
    prompt = (
        f"Can you plan a fun, friendly, {state['duration']}-day itinerary from {state['starting_point']} "
        f"to {state['destination']} with a budget of {state['budget']}?"
    )
    result = llm.invoke(prompt)
    print(f"\nYour itinerary:\n{result.content}\n")
    state['proposed_plan'] = result.content
    return state

def plan_approval(state: TripState) -> TripState:
    print("DEBUG1: Entering plan_approval with state", state)
    review = (
        f"Here’s your trip plan:\n\n{state.get('proposed_plan','none')}\n\n"
        "Are you satisfied? Type 'yes', 'proceed', or 'ok' to book flights, or request changes."
    )
    user_input = interrupt(review)
    print(f"DEBUG2: User input in approval: {user_input!r}")
    change_field = extract_change_field(user_input)
    print(f"DEBUG: LLM approval extraction: {change_field!r}")
    if change_field in ("proceed", "yes", "ok"):
        state['satisfied_with_plan'] = True
    elif change_field in FIELDS:
        state[change_field] = None
        state['satisfied_with_plan'] = None
    else:
        # For anything else, also check if user's direct text is "yes"/etc for robustness
        if user_input.strip().lower() in ("proceed", "yes", "ok"):
            state['satisfied_with_plan'] = True
        else:
            state['satisfied_with_plan'] = None
    return state


def plan_approval_router(state: TripState):
    print(f"DEBUG: In plan_approval_router, satisfied_with_plan={state.get('satisfied_with_plan')}")
    if state.get("satisfied_with_plan"):
        print("DEBUG: Plan approved; moving to flight booking.")
        return "ask_flight_details"
    missing = [fld for fld in FIELDS if not state.get(fld)]
    if missing:
        print(f"DEBUG: Editing slot(s) {missing}; will re-review.")
        return "review_info"
    print("DEBUG: General feedback; re-planning.")
    return "plan_trip"


def ask_flight_details(state: TripState) -> TripState:
    print("DEBUG: Entering ask_flight_details with state", state)
    src = interrupt(f"To book your flight, please confirm your departure city (or edit): [{state['starting_point']}]")
    dst = interrupt(f"And your arrival city? [{state['destination']}]")
    date = interrupt("On what date would you like to depart? (YYYY-MM-DD)")
    ret_type = interrupt("Is this a one-way or round-trip? (Type 'one-way' or 'round-trip')")
    state['flight_source'] = src or state['starting_point']
    state['flight_destination'] = dst or state['destination']
    state['flight_date'] = date
    state['return_trip'] = "round" in ret_type.lower()
    return state

def fetch_flights(state: TripState) -> TripState:
    print(f"DEBUG: Fetching flights {state['flight_source']} → {state['flight_destination']} on {state['flight_date']} (return: {state['return_trip']})")
    state['available_flights'] = [
        "AI101 | 8:00-10:30 | ₹6,300",
        "6E205 | 12:10-14:30 | ₹5,950",
        "G8 302 | 18:45-21:15 | ₹6,010"
    ]
    opts = "\n".join([f"{i+1}. {f}" for i, f in enumerate(state['available_flights'])])
    sel = interrupt(f"Here are some flight options:\n{opts}\nSelect a flight number:")
    try:
        ix = int(sel) - 1
        state['selected_flight'] = state['available_flights'][ix]
        print(f"DEBUG: User selected flight: {state['selected_flight']}")
    except Exception:
        state['selected_flight'] = None
        print("DEBUG: Invalid flight selection!")
    return state

def booking_confirmation(state: TripState) -> TripState:
    print("DEBUG: Entering booking_confirmation with state", state)
    if state.get("selected_flight"):
        print(f"\nBooking confirmed for: {state['selected_flight']}")
        state['done'] = True
    else:
        print("No flight selected. Ending flow.")
        state['done'] = True
    return state

# %%
graph = StateGraph(TripState)
graph.add_node("ask_starting_point", ask_starting_point)
graph.add_node("ask_destination", ask_destination)
graph.add_node("ask_budget", ask_budget)
graph.add_node("ask_duration", ask_duration)
graph.add_node("review_info", review_info)
graph.add_node("plan_trip", plan_trip)
graph.add_node("plan_approval", plan_approval)
graph.add_node("ask_flight_details", ask_flight_details)
graph.add_node("fetch_flights", fetch_flights)
graph.add_node("booking_confirmation", booking_confirmation)

graph.set_entry_point("ask_starting_point")
graph.add_edge("ask_starting_point", "ask_destination")
graph.add_edge("ask_destination", "ask_budget")
graph.add_edge("ask_budget", "ask_duration")
graph.add_edge("ask_duration", "review_info")
graph.add_conditional_edges(
    "review_info", review_router, {"review_info": "review_info", "plan_trip": "plan_trip"}
)
graph.add_edge("plan_trip", "plan_approval")
graph.add_conditional_edges(
    "plan_approval", plan_approval_router,
    {
        "plan_trip": "plan_trip",
        "ask_flight_details": "ask_flight_details",
        "review_info": "review_info"
    }
)
graph.add_edge("ask_flight_details", "fetch_flights")
graph.add_edge("fetch_flights", "booking_confirmation")
graph.add_edge("booking_confirmation", END)

# %%
checkpointer = MemorySaver()
workflow = graph.compile(checkpointer=checkpointer)

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

display(
    Image(
        workflow.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
thread_id = str(uuid.uuid4())
config = {"configurable": {"thread_id": thread_id}}
state = {}

result = workflow.invoke(state, config)
while True:
    if "__interrupt__" in result:
        user_input = input(result["__interrupt__"][0].value + " ")
        result = workflow.invoke(Command(resume=user_input), config)
        continue

    if result.get("done"):
        print("Trip complete!")
        break
# Out:
# DEBUG: Entering ask_starting_point with state
# DEBUG: Entering generate_slot_question()
# DEBUG: Generated question for 'starting_point': Sure thing! Where are you starting your adventure from? 🚗✈️
# DEBUG: Entering ask_starting_point with state
# DEBUG: Entering generate_slot_question()
# DEBUG: Generated question for 'starting_point': Sure thing! Where will you be starting your trip from? 🚀
# DEBUG: Entering extract_slot_value()
# DEBUG: Extracted value for starting_point: 'pune'
# DEBUG: Entering ask_destination with state
# DEBUG: Entering generate_slot_question()
# DEBUG: Generated question for 'destination': Where would you like to travel? 🚀✈️
# DEBUG: Entering ask_destination with state
# DEBUG: Entering generate_slot_question()
# DEBUG: Generated question for 'destination': Where would you like to travel to?
# DEBUG: Entering extract_slot_value()
# DEBUG: Extracted value for destination: 'mumbai'
# DEBUG: Entering ask_budget with state
# DEBUG: Entering generate_slot_question()
# DEBUG: Generated question for 'budget': Hey, just curious—what budget do you have in mind for this trip? 🌍💰
# DEBUG: Entering ask_budget with state
# DEBUG: Entering generate_slot_question()
# DEBUG: Generated question for 'budget': Sure thing! What budget are you thinking of setting for the trip? 😊
# DEBUG: Entering extract_slot_value()
# DEBUG: Extracted value for budget: '20000'
# DEBUG: Entering ask_duration with state
# DEBUG: Entering generate_slot_question()
# DEBUG: Generated question for 'duration': Sure thing! How many days would you like your trip to last?
# DEBUG: Entering ask_duration with state
# DEBUG: Entering generate_slot_question()
# DEBUG: Generated question for 'duration': Hey there! Just to make sure we get everything right, how many days would you like your trip to last? 😊
# DEBUG: Entering extract_slot_value()
# DEBUG: Extracted value for duration: '3 days'
# DEBUG: Entering review_info with state {'starting_point': 'pune', 'destination': 'mumbai', 'budget': '20000', 'duration': '3 days'}
# DEBUG: Entering review_info with state {'starting_point': 'pune', 'destination': 'mumbai', 'budget': '20000', 'duration': '3 days'}
# DEBUG: LLM slot change extraction: 'destination'
# DEBUG: type of change_field: <class 'str'>
# DEBUG: LLM extracted in review_info: destination
# DEBUG: LLM detected change request for field 'destination', resetting it.
# DEBUG: In review_router with state {'starting_point': 'pune', 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: In review_router, missing fields: ['destination']
# DEBUG: Entering review_info with state {'starting_point': 'pune', 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: Entering review_info with state {'starting_point': 'pune', 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: LLM slot change extraction: 'destination'
# DEBUG: type of change_field: <class 'str'>
# DEBUG: LLM extracted in review_info: destination
# DEBUG: LLM detected change request for field 'destination', resetting it.
# DEBUG: In review_router with state {'starting_point': 'pune', 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: In review_router, missing fields: ['destination']
# DEBUG: Entering review_info with state {'starting_point': 'pune', 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: Entering review_info with state {'starting_point': 'pune', 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: LLM slot change extraction: 'destination'
# DEBUG: type of change_field: <class 'str'>
# DEBUG: LLM extracted in review_info: destination
# DEBUG: LLM detected change request for field 'destination', resetting it.
# DEBUG: In review_router with state {'starting_point': 'pune', 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: In review_router, missing fields: ['destination']
# DEBUG: Entering review_info with state {'starting_point': 'pune', 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: Entering review_info with state {'starting_point': 'pune', 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: LLM slot change extraction: 'starting_point'
# DEBUG: type of change_field: <class 'str'>
# DEBUG: LLM extracted in review_info: starting_point
# DEBUG: LLM detected change request for field 'starting_point', resetting it.
# DEBUG: In review_router with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: In review_router, missing fields: ['starting_point', 'destination']
# DEBUG: Entering review_info with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: Entering review_info with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: Direct confirmation detected in review_info.
# DEBUG: In review_router with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: In review_router, missing fields: ['starting_point', 'destination']
# DEBUG: Entering review_info with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: Entering review_info with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: LLM slot change extraction: 'starting_point'
# DEBUG: type of change_field: <class 'str'>
# DEBUG: LLM extracted in review_info: starting_point
# DEBUG: LLM detected change request for field 'starting_point', resetting it.
# DEBUG: In review_router with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: In review_router, missing fields: ['starting_point', 'destination']
# DEBUG: Entering review_info with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: Entering review_info with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: LLM slot change extraction: 'proceed'
# DEBUG: type of change_field: <class 'str'>
# DEBUG: LLM extracted in review_info: proceed
# DEBUG: LLM confirmed proceed.
# DEBUG: In review_router with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: In review_router, missing fields: ['starting_point', 'destination']
# DEBUG: Entering review_info with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: Entering review_info with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: LLM slot change extraction: 'proceed'
# DEBUG: type of change_field: <class 'str'>
# DEBUG: LLM extracted in review_info: proceed
# DEBUG: LLM confirmed proceed.
# DEBUG: In review_router with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: In review_router, missing fields: ['starting_point', 'destination']
# DEBUG: Entering review_info with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: Entering review_info with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: LLM slot change extraction: 'proceed'
# DEBUG: type of change_field: <class 'str'>
# DEBUG: LLM extracted in review_info: proceed
# DEBUG: LLM confirmed proceed.
# DEBUG: In review_router with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: In review_router, missing fields: ['starting_point', 'destination']
# DEBUG: Entering review_info with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: Entering review_info with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: LLM slot change extraction: 'proceed'
# DEBUG: type of change_field: <class 'str'>
# DEBUG: LLM extracted in review_info: proceed
# DEBUG: LLM confirmed proceed.
# DEBUG: In review_router with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# DEBUG: In review_router, missing fields: ['starting_point', 'destination']
# DEBUG: Entering review_info with state {'starting_point': None, 'destination': None, 'budget': '20000', 'duration': '3 days', 'satisfied_with_plan': None}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 8
#       6 while True:
#       7     if "__interrupt__" in result:
# ----> 8         user_input = input(result["__interrupt__"][0].value + " ")
#       9         result = workflow.invoke(Command(resume=user_input), config)
#      10         continue
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File ~/Desktop/LangGraph_Project_Based_Learning/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
#    1439     # re-raise KeyboardInterrupt, to truncate traceback
#    1440     msg = "Interrupted by user"
# -> 1441     raise KeyboardInterrupt(msg) from None
#    1442 except Exception:
#    1443     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
## Amadeus Flight Booking API Key

# %% [markdown]
# ## Amadeus Flight Booking API Key

# %%
from amadeus import Client, ResponseError

amadeus = Client(
    client_id='',
    client_secret=''
)

try:
    response = amadeus.shopping.flight_offers_search.get(
        originLocationCode='BOM',
        destinationLocationCode='CCU',
        departureDate='2026-01-10',
        adults=1)
    print(response)
except Exception as error:
    print(error)
    print("Error occurred while fetching flight offers")
    pass
# Out:
# [---]
# Error occurred while fetching flight offers

# %%
from amadeus import Client, ResponseError

amadeus = Client(
    client_id='',
    client_secret='',
    hostname='production'
)

try:
    response = amadeus.shopping.flight_offers_search.get(
        originLocationCode='MAD',
        destinationLocationCode='ATH',
        departureDate='2024-11-01',
        adults=1)
    print(response.data)
except ResponseError as error:
    print(error)
# Out:
# [---]

# %%
for offer in response.data:
    print(f"Flight Offer: {offer['id']}, Price: {offer['price']['total']} {offer['price']['currency']}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 for offer in response.data:
#       2     print(f"Flight Offer: {offer['id']}, Price: {offer['price']['total']} {offer['price']['currency']}")
#
# NameError: name 'response' is not defined

# %% [markdown]
# ## FlightAPI

# %%
import requests

resp = requests.get('https://api.flightapi.io/iata/?name=mumbai&type=airport')
print (resp.json())
# Out:
# {'data': [{'iata': 'BOM', 'fs': 'BOM', 'name': 'Mumbai Chhatrapati Shivaji International Airport'}, {'iata': '', 'fs': 'VAJJ', 'name': 'Juhu Aerodrome'}, {'iata': 'NMI', 'fs': 'NMI', 'name': 'Navi Mumbai International Airport'}]}

# %%
import requests

url = "https://flight-fare-search.p.rapidapi.com/v2/flights/"

querystring = {"from":"BOM","to":"CCU","date":"2026-01-10","adult":"1","type":"economy","currency":"INR"}

headers = {
	"x-rapidapi-key": "",
	"x-rapidapi-host": "flight-fare-search.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

#flights= response.json()['results'][0:4]
#https://rapidapi.com/farish978/api/flight-fare-search
#https://rapidapi.com/search?term=flight&sortBy=ByRelevance

# %%
response.json()
# Out:
# {'status': 200,
#  'searchData': {'from': 'BOM',
#   'to': 'CCU',
#   'date': '2026-01-10',
#   'type': 'Economy',
#   'adult': 1,
#   'child': 0,
#   'infant': 0,
#   'currency': 'INR'},
#  'results': [{'id': '77fd3a601a59cb5033574c408d2046ab7b3df7a5cce8ff6785cc80ceb3011f4b',
#    'careerCode': 'IX',
#    'flight_code': 'IX-1176',
#    'flight_name': 'Air India Express',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': None,
#     'underSeat': None,
#     'baggageOptionsAvailable': True},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T07:10:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T20:10:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['IX-1176', 'IX-1532'],
#    'duration': {'text': '13h 00m', 'value': 780, 'unit': None},
#    'stopSummary': {'0': {'airport': 'IXB', 'stopDuration': 545},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 11019.53204,
#     'tax': None,
#     'base': 11019.53204}},
#   {'id': '8ec8e71128e150ad0d2fa8fa7588e6a88016d2c4670c25f13dd726e8e395c536',
#    'careerCode': 'IX',
#    'flight_code': 'IX-1176',
#    'flight_name': 'Air India Express',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': None,
#     'underSeat': None,
#     'baggageOptionsAvailable': True},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T07:10:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T15:45:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['IX-1176', 'IX-1259'],
#    'duration': {'text': '08h 35m', 'value': 515, 'unit': None},
#    'stopSummary': {'0': {'airport': 'IXB', 'stopDuration': 290},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 12956.39928,
#     'tax': None,
#     'base': 12956.39928}},
#   {'id': '679ee7d24efbc37f919094c240baead400bb5cb16540db44056ccb22b0d9c2d1',
#    'careerCode': 'AI',
#    'flight_code': 'AI-1851',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T15:35:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T23:15:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-1851', 'AI-1714'],
#    'duration': {'text': '07h 40m', 'value': 460, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 180},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 14704.8,
#     'tax': 2205.72,
#     'base': 12499.08}},
#   {'id': '13fe44f9c54d24c56fbf83b3dabb8303dc4e8d4ecaeefc95ad33ba3e1f05f249',
#    'careerCode': 'AI',
#    'flight_code': 'AI-573',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T17:00:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-11T00:35:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-573', 'AI-9783'],
#    'duration': {'text': '07h 35m', 'value': 455, 'unit': None},
#    'stopSummary': {'0': {'airport': 'MAA', 'stopDuration': 165},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 17155.6,
#     'tax': 2450.7999999999997,
#     'base': 14704.8}},
#   {'id': '0fe74103cc17a0dfbc05657d818c95e9374c04ff7758e9773d44c115f36bd4ed',
#    'careerCode': 'AI',
#    'flight_code': 'AI-1882',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T23:55:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-11T08:40:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-1882', 'AI-2535'],
#    'duration': {'text': '08h 45m', 'value': 525, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 265},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 16910.52,
#     'tax': 2450.7999999999997,
#     'base': 14459.72}},
#   {'id': '15cbdb62dc476f284738e6cee5252fba8d96db530744bf702fa45570924d0644',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2677',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T13:00:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-11T00:15:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2677', 'AI-2727'],
#    'duration': {'text': '11h 15m', 'value': 675, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 405},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 15440.039999999999,
#     'tax': 2205.72,
#     'base': 13234.32}},
#   {'id': '496ed787038432c34a31312b883631d8bb2a0595d04aaa31fa28a99394bf969f',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2677',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T13:00:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T23:15:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2677', 'AI-1714'],
#    'duration': {'text': '10h 15m', 'value': 615, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 345},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 16910.52,
#     'tax': 2450.7999999999997,
#     'base': 14459.72}},
#   {'id': 'e248894032cadd73bee025bfd0ced2236f5b6aa8887542fa1febcbbc6f3f149f',
#    'careerCode': 'AI',
#    'flight_code': 'AI-1851',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T15:35:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-11T00:15:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-1851', 'AI-2727'],
#    'duration': {'text': '08h 40m', 'value': 520, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 240},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 14704.8,
#     'tax': 2205.72,
#     'base': 12499.08}},
#   {'id': '90337c450f0851eea6795deae1c2cf2d521fe3f3248db98e7bb9021fc96cbc45',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2863',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T10:05:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T16:05:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2863', 'AI-9443'],
#    'duration': {'text': '06h 00m', 'value': 360, 'unit': None},
#    'stopSummary': {'0': {'airport': 'BLR', 'stopDuration': 95},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 29409.6,
#     'tax': 2940.96,
#     'base': 26468.64}},
#   {'id': '3afef28a10d2ef2963c72a8fc17b3496d370cb18a13cc2e574c6fc133dc77b7c',
#    'careerCode': 'HR',
#    'flight_code': 'H1-9136',
#    'flight_name': 'China United Airlines',
#    'stops': 'Direct',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': None,
#      'text': '1 PIECE',
#      'allowance': 1,
#      'refNumber': 2,
#      'totalWeight': None,
#      'perPieceWeight': 23,
#      'perPieceWeightFlag': 'AVERAGE'},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T09:35:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T12:25:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['H1-9136'],
#    'duration': {'text': '02h 50m', 'value': 170, 'unit': None},
#    'stopSummary': {'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 20586.719999999998,
#     'tax': 9313.039999999999,
#     'base': 11273.68}},
#   {'id': '5ead63da0716df0627af82fdfedadd574419b13836d782051e729bc5bb812087',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2677',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T13:00:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T20:15:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2677', 'AI-2403'],
#    'duration': {'text': '07h 15m', 'value': 435, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 165},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 16910.52,
#     'tax': 2450.7999999999997,
#     'base': 14459.72}},
#   {'id': '127261f9fb6947138c428193a8c4a3afebc2608a9d5d1fd6024f4211653a086b',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2428',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T08:00:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T15:15:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2428', 'AI-2767'],
#    'duration': {'text': '07h 15m', 'value': 435, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 160},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 14704.8,
#     'tax': 2205.72,
#     'base': 12499.08}},
#   {'id': '2fcd4d4151074ed8a4c3b24e96f5f79014d72371b6c974259f13cbcfebb1cd4f',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2986',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T22:45:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-11T04:15:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2986', 'AI-2702'],
#    'duration': {'text': '05h 30m', 'value': 330, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 50},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 16910.52,
#     'tax': 2450.7999999999997,
#     'base': 14459.72}},
#   {'id': '5aaf96c54d72938588710352a0814ba4ae681e26978da7b7f216b7ddfe01349f',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2944',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T14:25:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T23:15:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2944', 'AI-1714'],
#    'duration': {'text': '08h 50m', 'value': 530, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 260},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 14704.8,
#     'tax': 2205.72,
#     'base': 12499.08}},
#   {'id': '7541bdf2c73f945d4e96649ad64342367f8087202b709870075079377e50e841',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2910',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T17:25:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-11T04:15:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2910', 'AI-2702'],
#    'duration': {'text': '10h 50m', 'value': 650, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 375},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 13969.56,
#     'tax': 2205.72,
#     'base': 11763.84}},
#   {'id': '5fda34d02dbae4d4cea49cddaf2445718f75246f5be5647067cb5a1fc4a4ad4e',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2960',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T13:40:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T20:15:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2960', 'AI-2403'],
#    'duration': {'text': '06h 35m', 'value': 395, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 120},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 16910.52,
#     'tax': 2450.7999999999997,
#     'base': 14459.72}},
#   {'id': '10e8641fda4712909a5206308bf13ceaeaccd6b1a422e6f0253a572a09f84cea',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2996',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T18:30:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-11T00:15:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2996', 'AI-2727'],
#    'duration': {'text': '05h 45m', 'value': 345, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 75},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 14704.8,
#     'tax': 2205.72,
#     'base': 12499.08}},
#   {'id': '29a04e11204fe6d2bbf996256f0e7859cd76b2b73c0cfda9ecd7f2cc90923767',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2970',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T08:30:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T18:25:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2970', 'AI-1733'],
#    'duration': {'text': '09h 55m', 'value': 595, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 320},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 14704.8,
#     'tax': 2205.72,
#     'base': 12499.08}},
#   {'id': '3f074f40e20ba48412fa71e2ea9fb6088d7248c38c09b2d1f3dc10213251a97d',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2960',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T13:40:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T23:15:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2960', 'AI-1714'],
#    'duration': {'text': '09h 35m', 'value': 575, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 300},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 16910.52,
#     'tax': 2450.7999999999997,
#     'base': 14459.72}},
#   {'id': '3daecb14d496ddcaffeba8d6590037c1e866ae90566679b66f439d949a968d65',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2960',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T13:40:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-11T00:15:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2960', 'AI-2727'],
#    'duration': {'text': '10h 35m', 'value': 635, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 360},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 15440.039999999999,
#     'tax': 2205.72,
#     'base': 13234.32}},
#   {'id': '936d5527758821b8a6c77278745125bd6fa1e7622f7238242bc30e4ffb423789',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2771',
#    'flight_name': 'Air India',
#    'stops': 'Direct',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T06:55:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T09:50:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2771'],
#    'duration': {'text': '02h 55m', 'value': 175, 'unit': None},
#    'stopSummary': {'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 7842.5599999999995,
#     'tax': 1470.48,
#     'base': 6372.08}},
#   {'id': 'b3583c29f7011c225dd9809f74b5be96843886fe0e844d217e0c42643d50140f',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2773',
#    'flight_name': 'Air India',
#    'stops': 'Direct',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T14:05:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T16:50:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2773'],
#    'duration': {'text': '02h 45m', 'value': 165, 'unit': None},
#    'stopSummary': {'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 7842.5599999999995,
#     'tax': 1470.48,
#     'base': 6372.08}},
#   {'id': '1b25241f3c11b0d520aef4ffc24513ad3dbbf19b45ed09aaa201499544cf2bb5',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2411',
#    'flight_name': 'Air India',
#    'stops': 'Direct',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T19:20:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T22:10:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2411'],
#    'duration': {'text': '02h 50m', 'value': 170, 'unit': None},
#    'stopSummary': {'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 8332.72,
#     'tax': 1470.48,
#     'base': 6862.24}},
#   {'id': '2669f704fc47364a0bace0dbeaf7bc1b0c7f2d34de544c0cc0275ee7cd7330cd',
#    'careerCode': 'HR',
#    'flight_code': 'H1-2001',
#    'flight_name': 'China United Airlines',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': None,
#      'text': '1 PIECE',
#      'allowance': 1,
#      'refNumber': 2,
#      'totalWeight': None,
#      'perPieceWeight': 23,
#      'perPieceWeightFlag': 'AVERAGE'},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T16:05:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T22:30:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['H1-2001', 'H1-956'],
#    'duration': {'text': '06h 25m', 'value': 385, 'unit': None},
#    'stopSummary': {'0': {'airport': 'AMD', 'stopDuration': 140},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 37742.32,
#     'tax': 18135.92,
#     'base': 19606.399999999998}},
#   {'id': '7c3a812e20edd83c5ecff577cc7938d4c483f0bcaffdb75868d27c068e650bc3',
#    'careerCode': 'AI',
#    'flight_code': 'AI-866',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T04:05:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T11:45:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-866', 'AI-1791'],
#    'duration': {'text': '07h 40m', 'value': 460, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 190},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 14704.8,
#     'tax': 2205.72,
#     'base': 12499.08}},
#   {'id': '53423b7676f2f4661257ee6eb29b4806cd1ddae8da3ecc3e546f3e6e04d381c2',
#    'careerCode': 'AI',
#    'flight_code': 'AI-9485',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T17:00:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-11T00:15:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-9485', 'AI-2727'],
#    'duration': {'text': '07h 15m', 'value': 435, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 165},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 13969.56,
#     'tax': 2205.72,
#     'base': 11763.84}},
#   {'id': '04f10cda397225d80cc9c484b580f4fb54b4db53f7d69b03de9043aca19a937d',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2430',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T10:00:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T18:25:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-2430', 'AI-1733'],
#    'duration': {'text': '08h 25m', 'value': 505, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 235},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 15194.96,
#     'tax': 2205.72,
#     'base': 12989.24}},
#   {'id': '773d051ea915bfea01569fe6e3e0492424c162fab738e2ae0708c1df9c9fc78e',
#    'careerCode': 'AI',
#    'flight_code': 'AI-1882',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 0,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'K',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': 1,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T23:55:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-11T09:45:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['AI-1882', 'AI-2705'],
#    'duration': {'text': '09h 50m', 'value': 590, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 315},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 16910.52,
#     'tax': 2450.7999999999997,
#     'base': 14459.72}},
#   {'id': '3dad446d1ecdc67440b56da4e7e55cb785f7315fd75e81d41f1193952920217f',
#    'careerCode': 'AI',
#    'flight_code': 'AI-2432',
#    'flight_name': 'Air India',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': None,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
# ...
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-11T04:40:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['6E-102', '6E-2788'],
#    'duration': {'text': '07h 25m', 'value': 445, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 180},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 6274.048,
#     'tax': None,
#     'base': 6274.048}},
#   {'id': '8679204bedbd582306e3beed1039a72b59ff570c78160f7e381b05f5470a462b',
#    'careerCode': '6E',
#    'flight_code': '6E-138',
#    'flight_name': 'Indigo',
#    'stops': 'Direct',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': None,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T05:15:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T07:45:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['6E-138'],
#    'duration': {'text': '02h 30m', 'value': 150, 'unit': None},
#    'stopSummary': {'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 6935.764,
#     'tax': None,
#     'base': 6935.764}},
#   {'id': '39f9f6c83d410ee7e7bdd04bb07ca22b4c63d601a2bcc06f1e8915c4428e1b1a',
#    'careerCode': '6E',
#    'flight_code': '6E-6112',
#    'flight_name': 'Indigo',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': None,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T12:45:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T19:35:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['6E-6112', '6E-223'],
#    'duration': {'text': '06h 50m', 'value': 410, 'unit': None},
#    'stopSummary': {'0': {'airport': 'BLR', 'stopDuration': 145},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 9754.184,
#     'tax': None,
#     'base': 9754.184}},
#   {'id': 'ccc8a9157aaf6299df3fe2c820dc308ab66f2224e8a3ae19aea6021c071fc632',
#    'careerCode': '6E',
#    'flight_code': '6E-696',
#    'flight_name': 'Indigo',
#    'stops': 'Direct',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': None,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T20:15:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T22:50:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['6E-696'],
#    'duration': {'text': '02h 35m', 'value': 155, 'unit': None},
#    'stopSummary': {'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 10048.279999999999,
#     'tax': None,
#     'base': 10048.279999999999}},
#   {'id': '323eb339c50ae8ca5e91ebf128f0c53d2d02c6f72103342f71d1d93c2edad8fc',
#    'careerCode': '6E',
#    'flight_code': '6E-6613',
#    'flight_name': 'Indigo',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': None,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T19:10:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-11T01:45:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['6E-6613', '6E-2296'],
#    'duration': {'text': '06h 35m', 'value': 395, 'unit': None},
#    'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 160},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 8185.672,
#     'tax': None,
#     'base': 8185.672}},
#   {'id': '0779991a5c2780c55d7a0268cb9a478ecfe55578292d2b341762a27b24b594c5',
#    'careerCode': '6E',
#    'flight_code': '6E-5076',
#    'flight_name': 'Indigo',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': None,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T10:00:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T16:20:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['6E-5076', '6E-172'],
#    'duration': {'text': '06h 20m', 'value': 380, 'unit': None},
#    'stopSummary': {'0': {'airport': 'BLR', 'stopDuration': 110},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 6886.748,
#     'tax': None,
#     'base': 6886.748}},
#   {'id': 'ad337d273184c497c355387a4f65e8571545906bed38ed41a77f1753479838be',
#    'careerCode': '6E',
#    'flight_code': '6E-5246',
#    'flight_name': 'Indigo',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': None,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T08:20:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T14:05:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['6E-5246', '6E-376'],
#    'duration': {'text': '05h 45m', 'value': 345, 'unit': None},
#    'stopSummary': {'0': {'airport': 'HYD', 'stopDuration': 100},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 7474.94,
#     'tax': None,
#     'base': 7474.94}},
#   {'id': 'd4ff86809979883ae594cd693f6b7854d3f00ca8d3b5b7cd847c96f1c99de571',
#    'careerCode': '6E',
#    'flight_code': '6E-5228',
#    'flight_name': 'Indigo',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': None,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T16:55:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T23:55:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['6E-5228', '6E-6708'],
#    'duration': {'text': '07h 00m', 'value': 420, 'unit': None},
#    'stopSummary': {'0': {'airport': 'HYD', 'stopDuration': 200},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 6274.048,
#     'tax': None,
#     'base': 6274.048}},
#   {'id': '7a0e47b4aded0d64d988830d504db50ca15bedc7c97b34b182a167d61cd22766',
#    'careerCode': '6E',
#    'flight_code': '6E-5193',
#    'flight_name': 'Indigo',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': None,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T08:50:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T16:20:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['6E-5193', '6E-172'],
#    'duration': {'text': '07h 30m', 'value': 450, 'unit': None},
#    'stopSummary': {'0': {'airport': 'BLR', 'stopDuration': 110},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 8896.404,
#     'tax': None,
#     'base': 8896.404}},
#   {'id': '07a18fa7740c01bb378c67e7813a437e2b3d987e0d9b06690c295b79aaca853c',
#    'careerCode': '6E',
#    'flight_code': '6E-5296',
#    'flight_name': 'Indigo',
#    'stops': '1 Stop',
#    'cabinType': 'Economy',
#    'baggage': {'cabin': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '7 KG',
#      'allowance': 7,
#      'refNumber': None,
#      'totalWeight': None,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'checkIn': {'code': None,
#      'qty': 1,
#      'quantity': 1,
#      'dimensions': None,
#      'unit': 'KG',
#      'text': '15 KG',
#      'allowance': 15,
#      'refNumber': None,
#      'totalWeight': 15,
#      'perPieceWeight': None,
#      'perPieceWeightFlag': None},
#     'underSeat': None,
#     'baggageOptionsAvailable': False},
#    'currency': 'INR',
#    'departureAirport': {'time': '2026-01-10T07:30:00',
#     'code': 'BOM',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '1',
#     'label': 'Chhatrapati Shivaji International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Mumbai'},
#    'arrivalAirport': {'time': '2026-01-10T14:30:00',
#     'code': 'CCU',
#     'tz': 'Asia/Kolkata',
#     'timeZone': '5.50',
#     'type': '2',
#     'label': 'Netaji Subhas Chandra Bose International Airport',
#     'country': {'label': 'India', 'code': 'IN'},
#     'city': 'Kolkata'},
#    'path': ['6E-5296', '6E-312'],
#    'duration': {'text': '07h 00m', 'value': 420, 'unit': None},
#    'stopSummary': {'0': {'airport': 'BLR', 'stopDuration': 70},
#     'connectingTime': None},
#    'totals': {'currency': 'INR',
#     'baggage': None,
#     'penalty': None,
#     'total': 8896.404,
#     'tax': None,
#     'base': 8896.404}}]}

# %%
flights
# Out:
# [{'id': '2b56938f3c19dfdcc3aed0fd777765165392bbffe905bd83368f643fe364a807',
#   'careerCode': 'IX',
#   'flight_code': 'IX-1176',
#   'flight_name': 'Air India Express',
#   'stops': '1 Stop',
#   'cabinType': 'Economy',
#   'baggage': {'cabin': {'code': None,
#     'qty': 1,
#     'quantity': None,
#     'dimensions': None,
#     'unit': 'KG',
#     'text': '7 KG',
#     'allowance': 7,
#     'refNumber': None,
#     'totalWeight': None,
#     'perPieceWeight': None,
#     'perPieceWeightFlag': None},
#    'checkIn': None,
#    'underSeat': None,
#    'baggageOptionsAvailable': True},
#   'currency': 'INR',
#   'departureAirport': {'time': '2026-01-10T07:10:00',
#    'code': 'BOM',
#    'tz': 'Asia/Kolkata',
#    'timeZone': '5.50',
#    'type': '1',
#    'label': 'Chhatrapati Shivaji International Airport',
#    'country': {'label': 'India', 'code': 'IN'},
#    'city': 'Mumbai'},
#   'arrivalAirport': {'time': '2026-01-10T15:45:00',
#    'code': 'CCU',
#    'tz': 'Asia/Kolkata',
#    'timeZone': '5.50',
#    'type': '2',
#    'label': 'Netaji Subhas Chandra Bose International Airport',
#    'country': {'label': 'India', 'code': 'IN'},
#    'city': 'Kolkata'},
#   'path': ['IX-1176', 'IX-1259'],
#   'duration': {'text': '08h 35m', 'value': 515, 'unit': None},
#   'stopSummary': {'0': {'airport': 'IXB', 'stopDuration': 290},
#    'connectingTime': None},
#   'totals': {'currency': 'INR',
#    'baggage': None,
#    'penalty': None,
#    'total': 8938.44937,
#    'tax': None,
#    'base': 8938.44937}},
#  {'id': '71754bd724ce93369f5ad2c78a6c14a47ccf57195ef62238e36f6c80738affe5',
#   'careerCode': 'AI',
#   'flight_code': 'AI-1851',
#   'flight_name': 'Air India',
#   'stops': '1 Stop',
#   'cabinType': 'Economy',
#   'baggage': {'cabin': {'code': None,
#     'qty': 1,
#     'quantity': None,
#     'dimensions': None,
#     'unit': 'KG',
#     'text': '7 KG',
#     'allowance': 7,
#     'refNumber': None,
#     'totalWeight': None,
#     'perPieceWeight': None,
#     'perPieceWeightFlag': None},
#    'checkIn': {'code': None,
#     'qty': 0,
#     'quantity': 1,
#     'dimensions': None,
#     'unit': 'K',
#     'text': '15 KG',
#     'allowance': 15,
#     'refNumber': 1,
#     'totalWeight': 15,
#     'perPieceWeight': None,
#     'perPieceWeightFlag': None},
#    'underSeat': None,
#    'baggageOptionsAvailable': False},
#   'currency': 'INR',
#   'departureAirport': {'time': '2026-01-10T15:35:00',
#    'code': 'BOM',
#    'tz': 'Asia/Kolkata',
#    'timeZone': '5.50',
#    'type': '1',
#    'label': 'Chhatrapati Shivaji International Airport',
#    'country': {'label': 'India', 'code': 'IN'},
#    'city': 'Mumbai'},
#   'arrivalAirport': {'time': '2026-01-10T23:15:00',
#    'code': 'CCU',
#    'tz': 'Asia/Kolkata',
#    'timeZone': '5.50',
#    'type': '2',
#    'label': 'Netaji Subhas Chandra Bose International Airport',
#    'country': {'label': 'India', 'code': 'IN'},
#    'city': 'Kolkata'},
#   'path': ['AI-1851', 'AI-1714'],
#   'duration': {'text': '07h 40m', 'value': 460, 'unit': None},
#   'stopSummary': {'0': {'airport': 'DEL', 'stopDuration': 180},
#    'connectingTime': None},
#   'totals': {'currency': 'INR',
#    'baggage': None,
#    'penalty': None,
#    'total': 15681.92,
#    'tax': 2205.27,
#    'base': 13476.65}},
#  {'id': '521a2075e28d9be40fbf51bfd056f7f65a7734db8a5bae0d413cd977538a0273',
#   'careerCode': 'AI',
#   'flight_code': 'AI-2821',
#   'flight_name': 'Air India',
#   'stops': '1 Stop',
#   'cabinType': 'Economy',
#   'baggage': {'cabin': {'code': None,
#     'qty': 1,
#     'quantity': None,
#     'dimensions': None,
#     'unit': 'KG',
#     'text': '7 KG',
#     'allowance': 7,
#     'refNumber': None,
#     'totalWeight': None,
#     'perPieceWeight': None,
#     'perPieceWeightFlag': None},
#    'checkIn': {'code': None,
#     'qty': 0,
#     'quantity': 1,
#     'dimensions': None,
#     'unit': 'K',
#     'text': '15 KG',
#     'allowance': 15,
#     'refNumber': 1,
#     'totalWeight': 15,
#     'perPieceWeight': None,
#     'perPieceWeightFlag': None},
#    'underSeat': None,
#    'baggageOptionsAvailable': False},
#   'currency': 'INR',
#   'departureAirport': {'time': '2026-01-10T06:40:00',
#    'code': 'BOM',
#    'tz': 'Asia/Kolkata',
#    'timeZone': '5.50',
#    'type': '1',
#    'label': 'Chhatrapati Shivaji International Airport',
#    'country': {'label': 'India', 'code': 'IN'},
#    'city': 'Mumbai'},
#   'arrivalAirport': {'time': '2026-01-11T00:35:00',
#    'code': 'CCU',
#    'tz': 'Asia/Kolkata',
#    'timeZone': '5.50',
#    'type': '2',
#    'label': 'Netaji Subhas Chandra Bose International Airport',
#    'country': {'label': 'India', 'code': 'IN'},
#    'city': 'Kolkata'},
#   'path': ['AI-2821', 'AI-9783'],
#   'duration': {'text': '17h 55m', 'value': 1075, 'unit': None},
#   'stopSummary': {'0': {'airport': 'MAA', 'stopDuration': 790},
#    'connectingTime': None},
#   'totals': {'currency': 'INR',
#    'baggage': None,
#    'penalty': None,
#    'total': 16662.04,
#    'tax': 2450.3,
#    'base': 14211.74}},
#  {'id': 'a45955cdea28be59aabbe40d69d1d29c69cadc1bdfa3101803d83c72d2af6dc8',
#   'careerCode': 'AI',
#   'flight_code': 'AI-573',
#   'flight_name': 'Air India',
#   'stops': '1 Stop',
#   'cabinType': 'Economy',
#   'baggage': {'cabin': {'code': None,
#     'qty': 1,
#     'quantity': None,
#     'dimensions': None,
#     'unit': 'KG',
#     'text': '7 KG',
#     'allowance': 7,
#     'refNumber': None,
#     'totalWeight': None,
#     'perPieceWeight': None,
#     'perPieceWeightFlag': None},
#    'checkIn': {'code': None,
#     'qty': 0,
#     'quantity': 1,
#     'dimensions': None,
#     'unit': 'K',
#     'text': '15 KG',
#     'allowance': 15,
#     'refNumber': 1,
#     'totalWeight': 15,
#     'perPieceWeight': None,
#     'perPieceWeightFlag': None},
#    'underSeat': None,
#    'baggageOptionsAvailable': False},
#   'currency': 'INR',
#   'departureAirport': {'time': '2026-01-10T17:00:00',
#    'code': 'BOM',
#    'tz': 'Asia/Kolkata',
#    'timeZone': '5.50',
#    'type': '1',
#    'label': 'Chhatrapati Shivaji International Airport',
#    'country': {'label': 'India', 'code': 'IN'},
#    'city': 'Mumbai'},
#   'arrivalAirport': {'time': '2026-01-11T00:35:00',
#    'code': 'CCU',
#    'tz': 'Asia/Kolkata',
#    'timeZone': '5.50',
#    'type': '2',
#    'label': 'Netaji Subhas Chandra Bose International Airport',
#    'country': {'label': 'India', 'code': 'IN'},
#    'city': 'Kolkata'},
#   'path': ['AI-573', 'AI-9783'],
#   'duration': {'text': '07h 35m', 'value': 455, 'unit': None},
#   'stopSummary': {'0': {'airport': 'MAA', 'stopDuration': 165},
#    'connectingTime': None},
#   'totals': {'currency': 'INR',
#    'baggage': None,
#    'penalty': None,
#    'total': 13966.710000000001,
#    'tax': 2205.27,
#    'base': 11761.44}}]

# %%
for flight in flights:
    print(f"Flight: {flight['flight_code']} {flight['flight_name']}, Departure: {flight['departureAirport']['time']}, Arrival: {flight['arrivalAirport']['time']}, Price: {flight['totals']['total']} {flight['currency']}")
# Out:
# Flight: IX-1176 Air India Express, Departure: 2026-01-10T07:10:00, Arrival: 2026-01-10T15:45:00, Price: 8938.44937 INR
# Flight: AI-1851 Air India, Departure: 2026-01-10T15:35:00, Arrival: 2026-01-10T23:15:00, Price: 15681.92 INR
# Flight: AI-2821 Air India, Departure: 2026-01-10T06:40:00, Arrival: 2026-01-11T00:35:00, Price: 16662.04 INR
# Flight: AI-573 Air India, Departure: 2026-01-10T17:00:00, Arrival: 2026-01-11T00:35:00, Price: 13966.710000000001 INR

# %% [markdown]
# ## with real flight booking API

# %%
from typing import TypedDict, Optional
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import MemorySaver
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from langgraph.types import interrupt, Command
from amadeus import Client, ResponseError
import uuid
import os

class TripState(TypedDict):
    starting_point: Optional[str]
    destination: Optional[str]
    budget: Optional[str]
    duration: Optional[str]
    proposed_plan: Optional[str]
    satisfied_with_plan: Optional[bool]
    done: Optional[bool]
    selected_flight: Optional[str]
    flight_source: Optional[str]
    flight_destination: Optional[str]
    flight_date: Optional[str]
    return_trip: Optional[bool]
    available_flights: Optional[list]

amadeus = Client(
    client_id=os.getenv("AMADEUS_CLIENT_ID") or "YOUR_CLIENT_ID",
    client_secret=os.getenv("AMADEUS_CLIENT_SECRET") or "YOUR_CLIENT_SECRET"
)


def get_groq_llm() -> ChatOpenAI:
    return ChatOpenAI(
        model="openai/gpt-oss-20b",
        base_url="https://api.groq.com/openai/v1",
        api_key=os.getenv("GROQ_API_KEY"),
        temperature=0.7,
        max_tokens=2000
    )

llm = get_groq_llm()
FIELDS = ["starting_point", "destination", "budget", "duration"]
FIELD_QS = {
    "starting_point": "Ask the user for their trip starting location in a friendly way.",
    "destination": "Ask the user where they'd like to travel, naturally.",
    "budget": "Ask the user what budget they'd like to set for the trip, friendly and casual.",
    "duration": "Ask, in a conversational style, how many days they want their trip to last."
}

def generate_slot_question(slot_name):
    print("DEBUG: Entering generate_slot_question()")
    prompt = FIELD_QS[slot_name]
    response = llm.invoke(prompt).content.strip()
    print(f"DEBUG: Generated question for '{slot_name}': {response}")
    return response

def extract_slot_value(slot_name, user_input):
    print("DEBUG: Entering extract_slot_value()")
    prompt = (
        f"You are a smart assistant filling out a travel form.\n"
        f"The user was asked to specify their '{slot_name.replace('_', ' ')}'.\n"
        f"User replied: \"{user_input}\"\n"
        f"Extract and reply with ONLY the value for '{slot_name}'. If no clear value is found, reply 'None'."
    )
    response = llm.invoke(prompt).content.strip()
    if response.lower() == "none":
        response = None
    print(f"DEBUG: Extracted value for {slot_name}: '{response}'")
    return response

def extract_change_field(user_input: str) -> Optional[str]:
    """
    Detect which trip field (if any) the user wants to change, or if they want to proceed.
    Uses LLM for fuzzy detection, but is tolerant of natural human responses.
    """
    user_text = user_input.strip().lower()

    # --- Fast direct checks (no LLM call for simple confirmations) ---
    if any(word in user_text for word in ["proceed", "ok", "okay", "yes", "continue", "done", "confirm", "next", "go ahead", "move on"]):
        print("DEBUG: Direct 'proceed' detected without LLM.")
        return "proceed"

    # --- LLM fallback for detecting slot-change intent ---
    prompt = (
        "Decide which of these trip fields (if any) the user wants to update: "
        "starting_point, destination, budget, duration.\n"
        f"User said: \"{user_input}\"\n"
        "Reply ONLY with one of these: starting_point, destination, budget, duration, or 'proceed' if the user seems to approve or confirm."
    )

    try:
        result = llm.invoke(prompt).content.strip()
    except Exception as e:
        print(f"DEBUG: extract_change_field LLM error: {e}")
        return None

    print(f"DEBUG: LLM slot change extraction: '{result}'")

    # --- Interpret LLM output robustly ---
    for f in FIELDS:
        if f in result:
            return f
    if any(word in result for word in ["proceed", "ok", "okay", "yes", "continue", "done", "confirm", "next"]):
        return "proceed"

    return None


def ask_starting_point(state: TripState) -> TripState:
    print("DEBUG: Entering ask_starting_point with state")
    if not state.get("starting_point"):
        q = generate_slot_question("starting_point")
        user_input = interrupt(q)
        value = extract_slot_value("starting_point", user_input)
        state["starting_point"] = value
    return state

def ask_destination(state: TripState) -> TripState:
    print("DEBUG: Entering ask_destination with state")
    if not state.get("destination"):
        q = generate_slot_question("destination")
        user_input = interrupt(q)
        value = extract_slot_value("destination", user_input)
        state["destination"] = value
    return state

def ask_budget(state: TripState) -> TripState:
    print("DEBUG: Entering ask_budget with state")
    if not state.get("budget"):
        q = generate_slot_question("budget")
        user_input = interrupt(q)
        value = extract_slot_value("budget", user_input)
        state["budget"] = value
    return state

def ask_duration(state: TripState) -> TripState:
    print("DEBUG: Entering ask_duration with state")
    if not state.get("duration"):
        q = generate_slot_question("duration")
        user_input = interrupt(q)
        value = extract_slot_value("duration", user_input)
        state["duration"] = value
    return state

def review_info(state: TripState) -> TripState:
    print("DEBUG: Entering review_info with state", state)

    # Step 1. Build and show summary
    summary = (
        f"Please review your trip details:\n"
        f"- Starting point: {state.get('starting_point')}\n"
        f"- Destination: {state.get('destination')}\n"
        f"- Budget: {state.get('budget')}\n"
        f"- Duration: {state.get('duration')}\n"
        "Reply 'proceed' to confirm, or say what you'd like to change (e.g. 'change budget to 50k')."
    )

    # Step 2. Get user response
    user_input = interrupt(summary)
    user_text = user_input.strip().lower()

    # Step 3. If user confirms, exit review
    if any(x in user_text for x in ["proceed", "ok", "okay", "yes", "continue", "done", "confirm", "next", "go ahead"]):
        print("DEBUG: Direct confirmation detected. Proceeding to next step.")
        return state  # ✅ confirmed

    # Step 4. Detect which field they want to change
    change_field = extract_change_field(user_input)
    print(f"DEBUG: Field to change detected: {change_field}")

    # Step 5. Handle field update
    if change_field in FIELDS:
        ask_prompt = f"Sure! What should be the new {change_field.replace('_',' ')}?"
        new_value_input = interrupt(ask_prompt)
        new_value = extract_slot_value(change_field, new_value_input)
        state[change_field] = new_value
        print(f"DEBUG: Updated {change_field} → {new_value}")

        # ✅ After updating, re-enter review to show updated summary
        return review_info(state)

    # Step 6. If unclear, gently re-ask
    reask = interrupt("Sorry, I didn’t catch that. Would you like to proceed or update something?")
    if any(x in reask.lower() for x in ["proceed", "ok", "yes", "continue"]):
        return state

    return review_info(state)  # ✅ loop back again




def review_router(state: TripState):
    print("DEBUG: In review_router with state", state)
    missing = [fld for fld in FIELDS if not state.get(fld)]
    print(f"DEBUG: In review_router, missing fields: {missing}")
    if len(missing) > 0:
        return "review_info"
    return "plan_trip"

def plan_trip(state: TripState) -> TripState:
    print("DEBUG: Entering plan_trip with state", state)
    state['satisfied_with_plan'] = None
    prompt = (
        f"Can you plan a fun, friendly, {state['duration']}-day itinerary from {state['starting_point']} "
        f"to {state['destination']} with a budget of {state['budget']}?"
    )
    result = llm.invoke(prompt)
    print(f"\nYour itinerary:\n{result.content}\n")
    state['proposed_plan'] = result.content
    return state

def plan_approval(state: TripState) -> TripState:
    print("DEBUG1: Entering plan_approval with state", state)
    review = (
        f"Here’s your trip plan:\n\n{state.get('proposed_plan','none')}\n\n"
        "Are you satisfied? Type 'yes', 'proceed', or 'ok' to book flights, or request changes."
    )
    user_input = interrupt(review)
    print(f"DEBUG2: User input in approval: {user_input!r}")
    change_field = extract_change_field(user_input)
    print(f"DEBUG: LLM approval extraction: {change_field!r}")
    if change_field in ("proceed", "yes", "ok"):
        state['satisfied_with_plan'] = True
    elif change_field in FIELDS:
        state[change_field] = None
        state['satisfied_with_plan'] = None
    else:
        # For anything else, also check if user's direct text is "yes"/etc for robustness
        if user_input.strip().lower() in ("proceed", "yes", "ok"):
            state['satisfied_with_plan'] = True
        else:
            state['satisfied_with_plan'] = None
    return state


def plan_approval_router(state: TripState):
    print(f"DEBUG: In plan_approval_router, satisfied_with_plan={state.get('satisfied_with_plan')}")
    if state.get("satisfied_with_plan"):
        print("DEBUG: Plan approved; moving to flight booking.")
        return "ask_flight_details"
    missing = [fld for fld in FIELDS if not state.get(fld)]
    if missing:
        print(f"DEBUG: Editing slot(s) {missing}; will re-review.")
        return "review_info"
    print("DEBUG: General feedback; re-planning.")
    return "plan_trip"




def ask_flight_details(state: TripState) -> TripState:
    print("DEBUG: Entering ask_flight_details with state", state)
    src = interrupt(f"To book your flight, please confirm your departure city (or edit): [{state['starting_point']}]")
    dst = interrupt(f"And your arrival city? [{state['destination']}]")
    date = interrupt("On what date would you like to depart? (YYYY-MM-DD)")
    ret_type = interrupt("Is this a one-way or round-trip? (Type 'one-way' or 'round-trip')")
    state['flight_source'] = src or state['starting_point']
    state['flight_destination'] = dst or state['destination']
    state['flight_date'] = date
    state['return_trip'] = "round" in ret_type.lower()
    return state

# def get_airport_code(city_name: str) -> str:
#     """Convert city name to IATA code using Amadeus API."""
#     try:
#         response = amadeus.reference_data.locations.get(
#             keyword=city_name,
#             subType='AIRPORT'
#         )
#         if response.data:
#             return response.data[0]['iataCode']
#     except ResponseError as e:
#         print(f"ERROR fetching airport code for {city_name}: {e}")
#     return None

FLIGHTAPI_KEY = ""  # move to env in prod

def get_airport_code(city_name: str) -> str | None:
    """
    Convert city name to IATA airport code using FlightAPI.
    """
    url = f"https://api.flightapi.io/iata/{FLIGHTAPI_KEY}"
    params = {
        "name": city_name,
        "type": "airport"
    }

    try:
        resp = requests.get(url, params=params, timeout=20)
        resp.raise_for_status()
        payload = resp.json()
        #print(payload)
        airports = payload.get("data", [])
        if airports:
            return airports[0].get("iata")

    except Exception as e:
        print(f"ERROR fetching airport code for {city_name}: {e}")

    return None

# def fetch_flights(state: dict) -> dict:
#     source_city = state.get('starting_point', '')
#     dest_city = state.get('destination', '')
#     travel_date = state.get('flight_date', '2025-11-01')  # default date fallback

#     print(f"DEBUG: Fetching flights from {source_city} → {dest_city} on {travel_date}")

#     origin_code = get_airport_code(source_city) or source_city.upper()
#     dest_code = get_airport_code(dest_city) or dest_city.upper()

#     print(f"DEBUG: Using airport codes {origin_code} → {dest_code}")

#     try:
#         response = amadeus.shopping.flight_offers_search.get(
#             originLocationCode=origin_code,
#             destinationLocationCode=dest_code,
#             departureDate=travel_date,
#             adults=1,
#             max=5
#         )
#         offers = response.data
#     except ResponseError as error:
#         print("ERROR fetching flights:", error)
#         offers = []

#     if not offers:
#         sel = interrupt(f"Sorry, couldn't find flights from {source_city} to {dest_city}. Try another route?")
#         state['selected_flight'] = None
#         return state

#     # Prepare display list
#     opts = []
#     for i, offer in enumerate(offers):
#         seg = offer["itineraries"][0]["segments"][0]
#         airline = seg["carrierCode"]
#         depart_time = seg["departure"]["at"]
#         arrive_time = seg["arrival"]["at"]
#         price = offer["price"]["total"]
#         currency = offer["price"]["currency"]
#         opts.append(f"{i+1}. {airline} | {depart_time} → {arrive_time} | {price} {currency}")

#     opts_text = "\n".join(opts)
#     sel = interrupt(f"Here are some real flights from {source_city} to {dest_city}:\n{opts_text}\nSelect a flight number:")

#     try:
#         ix = int(sel) - 1
#         if 0 <= ix < len(offers):
#             state['selected_flight'] = offers[ix]
#         else:
#             state['selected_flight'] = None
#     except ValueError:
#         state['selected_flight'] = None

#     return state

import requests

RAPIDAPI_KEY = ""

def fetch_flights(state: dict) -> dict:
    source_city = state.get("flight_source") or state.get("starting_point", "")
    dest_city = state.get("flight_destination") or state.get("destination", "")
    travel_date = state.get("flight_date", "2026-01-10")

    print(f"DEBUG: Fetching flights {source_city} → {dest_city} on {travel_date}")

    origin_code = get_airport_code(source_city) or source_city.upper()
    dest_code = get_airport_code(dest_city) or dest_city.upper()

    url = "https://flight-fare-search.p.rapidapi.com/v2/flights/"
    querystring = {
        "from": origin_code,
        "to": dest_code,
        "date": travel_date,
        "adult": "1",
        "type": "economy",
        "currency": "INR"
    }

    headers = {
        "x-rapidapi-key": RAPIDAPI_KEY,
        "x-rapidapi-host": "flight-fare-search.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring, timeout=20)
    flights = response.json().get("results", [])[:4]

    if not flights:
        interrupt("Sorry, no flights found for this route.")
        return state

    # Show options
    options = []
    for i, flight in enumerate(flights):
        options.append(
            f"{i+1}. {flight['flight_code']} {flight['flight_name']} | "
            f"{flight['departureAirport']['time']} → {flight['arrivalAirport']['time']} | "
            f"{flight['totals']['total']} {flight['currency']}"
        )

    # ⬅️ THIS is the key line
    choice = interrupt(
        "Here are available flights:\n"
        + "\n".join(options)
        + "\n\nSelect a flight number:"
    )

    # ⬅️ This runs AFTER resume
    try:
        idx = int(choice) - 1
        if 0 <= idx < len(flights):
            state["selected_flight"] = flights[idx]
            print("DEBUG: Flight selected successfully")
        else:
            state["selected_flight"] = None
    except ValueError:
        state["selected_flight"] = None

    return state




def booking_confirmation(state: dict) -> dict:
    flight = state.get("selected_flight")

    print("DEBUG booking_confirmation selected_flight:", state.get("selected_flight"))

    if not flight:
        interrupt("No flight was selected. Ending the booking flow.")
        state["done"] = True
        return state

    # 🔹 RapidAPI flight schema (matches fetch_flights)
    airline = flight.get("flight_name")
    flight_code = flight.get("flight_code")

    depart_airport = flight.get("departureAirport", {})
    arrive_airport = flight.get("arrivalAirport", {})

    depart_time = depart_airport.get("time")
    arrive_time = arrive_airport.get("time")

    price = flight.get("totals", {}).get("total")
    currency = flight.get("currency")

    confirm = interrupt(
        f"You selected **{airline} ({flight_code})**\n"
        f"✈️ {depart_time} → {arrive_time}\n"
        f"💰 Price: {price} {currency}\n\n"
        f"Would you like to confirm the booking? (yes/no)"
    )

    if confirm.strip().lower() in ("yes", "y"):
        print(f"✅ Booking confirmed for {airline} ({flight_code})!")
        state["done"] = True
        state["booking_status"] = "confirmed"
    else:
        print("❌ Booking cancelled by user.")
        state["done"] = True
        state["booking_status"] = "cancelled"

    return state



graph = StateGraph(TripState)
graph.add_node("ask_starting_point", ask_starting_point)
graph.add_node("ask_destination", ask_destination)
graph.add_node("ask_budget", ask_budget)
graph.add_node("ask_duration", ask_duration)
graph.add_node("review_info", review_info)
graph.add_node("plan_trip", plan_trip)
graph.add_node("plan_approval", plan_approval)
graph.add_node("ask_flight_details", ask_flight_details)
graph.add_node("fetch_flights", fetch_flights)
graph.add_node("booking_confirmation", booking_confirmation)

graph.set_entry_point("ask_starting_point")
graph.add_edge("ask_starting_point", "ask_destination")
graph.add_edge("ask_destination", "ask_budget")
graph.add_edge("ask_budget", "ask_duration")
graph.add_edge("ask_duration", "review_info")
graph.add_conditional_edges(
    "review_info", review_router, {"review_info": "review_info", "plan_trip": "plan_trip"}
)
graph.add_edge("plan_trip", "plan_approval")
graph.add_conditional_edges(
    "plan_approval", plan_approval_router,
    {
        "plan_trip": "plan_trip",
        "ask_flight_details": "ask_flight_details",
        "review_info": "review_info"
    }
)
graph.add_edge("ask_flight_details", "fetch_flights")
graph.add_edge("fetch_flights", "booking_confirmation")
graph.add_edge("booking_confirmation", END)

# %%
checkpointer = MemorySaver()
workflow = graph.compile(checkpointer=checkpointer)

# %%
workflow

# %%
thread_id = str(uuid.uuid4())
config = {"configurable": {"thread_id": thread_id}}
state = {}

result = workflow.invoke(state, config)
# while True:
#     interrupts = getattr(result, "__interrupt__", None)

#     if interrupts:
#         intr = interrupts[0]  # active interrupt
#         user_input = input(intr.value + " ")

#         result = workflow.invoke(
#             Command(resume={intr.id: user_input}),
#             config
#         )
#         continue

#     if result.get("done"):
#         print("Trip complete!")
#         break


while True: 
    if "__interrupt__" in result: 
        user_input = input(result["__interrupt__"][0].value + " ") 
        result = workflow.invoke(Command(resume=user_input), config) 
        continue 
    if result.get("done"): 
        print("Trip complete!") 
        break
# Out:
# DEBUG: Entering ask_starting_point with state
# DEBUG: Entering generate_slot_question()
# DEBUG: Generated question for 'starting_point': Sure thing! Where will you be starting your adventure from? 🚗✨
# DEBUG: Entering ask_starting_point with state
# DEBUG: Entering generate_slot_question()
# DEBUG: Generated question for 'starting_point': Absolutely! Where are you starting your trip from? 🚗✈️
# DEBUG: Entering extract_slot_value()
# DEBUG: Extracted value for starting_point: 'mumbai'
# DEBUG: Entering ask_destination with state
# DEBUG: Entering generate_slot_question()
# DEBUG: Generated question for 'destination': Where would you like to travel? 🌍✈️
# DEBUG: Entering ask_destination with state
# DEBUG: Entering generate_slot_question()
# DEBUG: Generated question for 'destination': Got it! Where would you like to travel?
# DEBUG: Entering extract_slot_value()
# DEBUG: Extracted value for destination: 'Kolkata'
# DEBUG: Entering ask_budget with state
# DEBUG: Entering generate_slot_question()
# DEBUG: Generated question for 'budget': Hey there! Just curious—what budget were you thinking of setting for your trip? Feel free to be as flexible or specific as you’d like!
# DEBUG: Entering ask_budget with state
# DEBUG: Entering generate_slot_question()
# DEBUG: Generated question for 'budget': What kinda budget are you thinking of for this trip? Just let me know a ball‑park and we can start shaping everything around that.
# DEBUG: Entering extract_slot_value()
# DEBUG: Extracted value for budget: '20000'
# DEBUG: Entering ask_duration with state
# DEBUG: Entering generate_slot_question()
# DEBUG: Generated question for 'duration': How many days would you like your trip to last?
# DEBUG: Entering ask_duration with state
# DEBUG: Entering generate_slot_question()
# DEBUG: Generated question for 'duration': Hey! Just checking in—how many days are you thinking about for your trip?
# DEBUG: Entering extract_slot_value()
# DEBUG: Extracted value for duration: '3 days'
# DEBUG: Entering review_info with state {'starting_point': 'mumbai', 'destination': 'Kolkata', 'budget': '20000', 'duration': '3 days'}
# DEBUG: Entering review_info with state {'starting_point': 'mumbai', 'destination': 'Kolkata', 'budget': '20000', 'duration': '3 days'}
# DEBUG: LLM slot change extraction: 'budget'
# DEBUG: Field to change detected: budget
# DEBUG: Entering review_info with state {'starting_point': 'mumbai', 'destination': 'Kolkata', 'budget': '20000', 'duration': '3 days'}
# DEBUG: LLM slot change extraction: 'budget'
# DEBUG: Field to change detected: budget
# DEBUG: Entering extract_slot_value()
# DEBUG: Extracted value for budget: '18000'
# DEBUG: Updated budget → 18000
# DEBUG: Entering review_info with state {'starting_point': 'mumbai', 'destination': 'Kolkata', 'budget': '18000', 'duration': '3 days'}
# DEBUG: Entering review_info with state {'starting_point': 'mumbai', 'destination': 'Kolkata', 'budget': '20000', 'duration': '3 days'}
# DEBUG: LLM slot change extraction: 'budget'
# DEBUG: Field to change detected: budget
# DEBUG: Entering extract_slot_value()
# DEBUG: Extracted value for budget: '18000'
# DEBUG: Updated budget → 18000
# DEBUG: Entering review_info with state {'starting_point': 'mumbai', 'destination': 'Kolkata', 'budget': '18000', 'duration': '3 days'}
# DEBUG: Direct confirmation detected. Proceeding to next step.
# DEBUG: In review_router with state {'starting_point': 'mumbai', 'destination': 'Kolkata', 'budget': '18000', 'duration': '3 days'}
# DEBUG: In review_router, missing fields: []
# DEBUG: Entering plan_trip with state {'starting_point': 'mumbai', 'destination': 'Kolkata', 'budget': '18000', 'duration': '3 days'}
#
# Your itinerary:
# ### 3‑Day “Mumbai → Kolkata” Adventure on ₹18,000
# *(All prices are approximate and can vary with season, booking time, and personal choices. I’ve rounded up to give you a comfortable cushion.)*
#
# | Item | Approx. Cost (₹) | Notes |
# |------|------------------|-------|
# | **Mumbai → Kolkata (train, 3‑tier AC)** | 1,800 | Book early on IRCTC or a travel portal. Overnight Rajdhani or Duronto gives you a good seat and meals. |
# | **Kolkata → Mumbai (train, 3‑tier AC)** | 1,800 | Same class, same comfort. |
# | **Accommodation (2 nights, budget hotel/hostel)** | 4,000 | ₹2,000/night (e.g., Hotel Shanti, OYO 3‑star, or a hostel dorm). |
# | **Food (3 days)** | 2,700 | Breakfast ₹200, Lunch ₹300, Dinner ₹400 per day. |
# | **Local transport (auto/metro)** | 600 | ₹200/day for rickshaws, auto, or metro. |
# | **Entrance fees & small extras** | 400 | Museum tickets, temple donations, small souvenirs. |
# | **Buffer & emergencies** | 1,200 | Unexpected taxi, extra snack, or a souvenir. |
# | ****Total** | **≈ 18,000** | Leaves a little room for spontaneous fun. |
#
# > **Tip:** If you’re flexible with dates, book your trains at least 4–6 weeks in advance to lock in the lowest fares. Use the “Railway Enquiry” app or IRCTC to compare coaches and choose the one with the best view.
#
# ---
#
# ## Day‑by‑Day Itinerary
#
# | Time | Activity | Where & How |
# |------|----------|-------------|
# | **Day 0 – Evening** | **Board the overnight train** from Mumbai CST to Sealdah. | 8:00 PM – 8:00 AM (next day). |
# | **Day 1 – Morning** | **Arrive in Kolkata** at 8 AM. | Take a short auto or metro ride to your hotel. |
# | | **Check‑in & refresh** | 10:00 AM – 11:00 AM. |
# | | **Breakfast** | Hotel or a local chai‑tea stall (₹200). |
# | | **Victoria Memorial** | 11:30 AM – 1:30 PM. Take a metro or auto; entrance ₹30. |
# | | **Lunch** | 1:45 PM – 2:30 PM at a local eatery (e.g., Biryani House, ₹300). |
# | | **Howrah Bridge** | 3:00 PM – 3:30 PM. Walk across, capture photos. |
# | | **Park Street** | 4:00 PM – 6:00 PM. Explore cafés, shop for a souvenir. |
# | | **Dinner** | 7:00 PM – 8:30 PM at a budget‑friendly place (e.g., Khandwa, ₹400). |
# | | **Night** | Optional: a short stroll along the river or a quick metro ride back to the hotel. |
# | **Day 2 – Full Day** | **Breakfast** | 8:00 AM – 8:30 AM. |
# | | **Dakshineswar Kali Temple** | 9:00 AM – 10:30 AM. Take a ferry or auto; donation ₹20. |
# | | **Kumartuli** | 11:00 AM – 12:30 PM. Watch artisans at work. |
# | | **Lunch** | 1:00 PM – 1:45 PM at a local spot (₹300). |
# | | **Indian Museum** | 2:30 PM – 4:30 PM. Entrance ₹10. |
# | | **College Street** | 5:00 PM – 6:00 PM. Browse book stalls, grab a snack. |
# | | **Dinner** | 7:00 PM – 8:30 PM at a budget restaurant (₹400). |
# | | **Night** | Relax at the hotel or enjoy a local street food (₹200). |
# | **Day 3 – Morning & Departure** | **Breakfast** | 7:30 AM – 8:00 AM. |
# | | **Morning walk at Marble Palace or a quick visit to the St. Paul’s Cathedral** | 8:30 AM – 9:30 AM. |
# | | **Check‑out** | 10:00 AM. |
# | | **Last‑minute shopping at New Market** | 10:30 AM – 11:30 AM. |
# | | **Lunch** | 12:00 PM – 12:45 PM (₹300). |
# | | **Board the return train** | 5:00 PM – 5:00 AM (next day). |
# | | **Arrive back in Mumbai** | 5:00 AM. |
#
# ---
#
# ##
#
# DEBUG1: Entering plan_approval with state {'starting_point': 'mumbai', 'destination': 'Kolkata', 'budget': '18000', 'duration': '3 days', 'proposed_plan': '### 3‑Day “Mumbai\u202f→\u202fKolkata” Adventure on ₹18,000  \n*(All prices are approximate and can vary with season, booking time, and personal choices. I’ve rounded up to give you a comfortable cushion.)*\n\n| Item | Approx. Cost (₹) | Notes |\n|------|------------------|-------|\n| **Mumbai → Kolkata (train, 3‑tier AC)** | 1,800 | Book early on IRCTC or a travel portal. Overnight Rajdhani or Duronto gives you a good seat and meals. |\n| **Kolkata → Mumbai (train, 3‑tier AC)** | 1,800 | Same class, same comfort. |\n| **Accommodation (2 nights, budget hotel/hostel)** | 4,000 | ₹2,000/night (e.g., Hotel Shanti, OYO 3‑star, or a hostel dorm). |\n| **Food (3 days)** | 2,700 | Breakfast ₹200, Lunch ₹300, Dinner ₹400 per day. |\n| **Local transport (auto/metro)** | 600 | ₹200/day for rickshaws, auto, or metro. |\n| **Entrance fees & small extras** | 400 | Museum tickets, temple donations, small souvenirs. |\n| **Buffer & emergencies** | 1,200 | Unexpected taxi, extra snack, or a souvenir. |\n| ****Total** | **≈\u202f18,000** | Leaves a little room for spontaneous fun. |\n\n> **Tip:** If you’re flexible with dates, book your trains at least 4–6\u202fweeks in advance to lock in the lowest fares. Use the “Railway Enquiry” app or IRCTC to compare coaches and choose the one with the best view.\n\n---\n\n## Day‑by‑Day Itinerary\n\n| Time | Activity | Where & How |\n|------|----------|-------------|\n| **Day 0 – Evening** | **Board the overnight train** from Mumbai CST to Sealdah. | 8:00\u202fPM – 8:00\u202fAM (next day). |\n| **Day 1 – Morning** | **Arrive in Kolkata** at 8\u202fAM. | Take a short auto or metro ride to your hotel. |\n| | **Check‑in & refresh** | 10:00\u202fAM – 11:00\u202fAM. |\n| | **Breakfast** | Hotel or a local chai‑tea stall (₹200). |\n| | **Victoria Memorial** | 11:30\u202fAM – 1:30\u202fPM. Take a metro or auto; entrance ₹30. |\n| | **Lunch** | 1:45\u202fPM – 2:30\u202fPM at a local eatery (e.g., Biryani House, ₹300). |\n| | **Howrah Bridge** | 3:00\u202fPM – 3:30\u202fPM. Walk across, capture photos. |\n| | **Park Street** | 4:00\u202fPM – 6:00\u202fPM. Explore cafés, shop for a souvenir. |\n| | **Dinner** | 7:00\u202fPM – 8:30\u202fPM at a budget‑friendly place (e.g., Khandwa, ₹400). |\n| | **Night** | Optional: a short stroll along the river or a quick metro ride back to the hotel. |\n| **Day 2 – Full Day** | **Breakfast** | 8:00\u202fAM – 8:30\u202fAM. |\n| | **Dakshineswar Kali Temple** | 9:00\u202fAM – 10:30\u202fAM. Take a ferry or auto; donation ₹20. |\n| | **Kumartuli** | 11:00\u202fAM – 12:30\u202fPM. Watch artisans at work. |\n| | **Lunch** | 1:00\u202fPM – 1:45\u202fPM at a local spot (₹300). |\n| | **Indian Museum** | 2:30\u202fPM – 4:30\u202fPM. Entrance ₹10. |\n| | **College Street** | 5:00\u202fPM – 6:00\u202fPM. Browse book stalls, grab a snack. |\n| | **Dinner** | 7:00\u202fPM – 8:30\u202fPM at a budget restaurant (₹400). |\n| | **Night** | Relax at the hotel or enjoy a local street food (₹200). |\n| **Day 3 – Morning & Departure** | **Breakfast** | 7:30\u202fAM – 8:00\u202fAM. |\n| | **Morning walk at Marble Palace or a quick visit to the St. Paul’s Cathedral** | 8:30\u202fAM – 9:30\u202fAM. |\n| | **Check‑out** | 10:00\u202fAM. |\n| | **Last‑minute shopping at New Market** | 10:30\u202fAM – 11:30\u202fAM. |\n| | **Lunch** | 12:00\u202fPM – 12:45\u202fPM (₹300). |\n| | **Board the return train** | 5:00\u202fPM – 5:00\u202fAM (next day). |\n| | **Arrive back in Mumbai** | 5:00\u202fAM. |\n\n---\n\n##', 'satisfied_with_plan': None}
# DEBUG1: Entering plan_approval with state {'starting_point': 'mumbai', 'destination': 'Kolkata', 'budget': '18000', 'duration': '3 days', 'proposed_plan': '### 3‑Day “Mumbai\u202f→\u202fKolkata” Adventure on ₹18,000  \n*(All prices are approximate and can vary with season, booking time, and personal choices. I’ve rounded up to give you a comfortable cushion.)*\n\n| Item | Approx. Cost (₹) | Notes |\n|------|------------------|-------|\n| **Mumbai → Kolkata (train, 3‑tier AC)** | 1,800 | Book early on IRCTC or a travel portal. Overnight Rajdhani or Duronto gives you a good seat and meals. |\n| **Kolkata → Mumbai (train, 3‑tier AC)** | 1,800 | Same class, same comfort. |\n| **Accommodation (2 nights, budget hotel/hostel)** | 4,000 | ₹2,000/night (e.g., Hotel Shanti, OYO 3‑star, or a hostel dorm). |\n| **Food (3 days)** | 2,700 | Breakfast ₹200, Lunch ₹300, Dinner ₹400 per day. |\n| **Local transport (auto/metro)** | 600 | ₹200/day for rickshaws, auto, or metro. |\n| **Entrance fees & small extras** | 400 | Museum tickets, temple donations, small souvenirs. |\n| **Buffer & emergencies** | 1,200 | Unexpected taxi, extra snack, or a souvenir. |\n| ****Total** | **≈\u202f18,000** | Leaves a little room for spontaneous fun. |\n\n> **Tip:** If you’re flexible with dates, book your trains at least 4–6\u202fweeks in advance to lock in the lowest fares. Use the “Railway Enquiry” app or IRCTC to compare coaches and choose the one with the best view.\n\n---\n\n## Day‑by‑Day Itinerary\n\n| Time | Activity | Where & How |\n|------|----------|-------------|\n| **Day 0 – Evening** | **Board the overnight train** from Mumbai CST to Sealdah. | 8:00\u202fPM – 8:00\u202fAM (next day). |\n| **Day 1 – Morning** | **Arrive in Kolkata** at 8\u202fAM. | Take a short auto or metro ride to your hotel. |\n| | **Check‑in & refresh** | 10:00\u202fAM – 11:00\u202fAM. |\n| | **Breakfast** | Hotel or a local chai‑tea stall (₹200). |\n| | **Victoria Memorial** | 11:30\u202fAM – 1:30\u202fPM. Take a metro or auto; entrance ₹30. |\n| | **Lunch** | 1:45\u202fPM – 2:30\u202fPM at a local eatery (e.g., Biryani House, ₹300). |\n| | **Howrah Bridge** | 3:00\u202fPM – 3:30\u202fPM. Walk across, capture photos. |\n| | **Park Street** | 4:00\u202fPM – 6:00\u202fPM. Explore cafés, shop for a souvenir. |\n| | **Dinner** | 7:00\u202fPM – 8:30\u202fPM at a budget‑friendly place (e.g., Khandwa, ₹400). |\n| | **Night** | Optional: a short stroll along the river or a quick metro ride back to the hotel. |\n| **Day 2 – Full Day** | **Breakfast** | 8:00\u202fAM – 8:30\u202fAM. |\n| | **Dakshineswar Kali Temple** | 9:00\u202fAM – 10:30\u202fAM. Take a ferry or auto; donation ₹20. |\n| | **Kumartuli** | 11:00\u202fAM – 12:30\u202fPM. Watch artisans at work. |\n| | **Lunch** | 1:00\u202fPM – 1:45\u202fPM at a local spot (₹300). |\n| | **Indian Museum** | 2:30\u202fPM – 4:30\u202fPM. Entrance ₹10. |\n| | **College Street** | 5:00\u202fPM – 6:00\u202fPM. Browse book stalls, grab a snack. |\n| | **Dinner** | 7:00\u202fPM – 8:30\u202fPM at a budget restaurant (₹400). |\n| | **Night** | Relax at the hotel or enjoy a local street food (₹200). |\n| **Day 3 – Morning & Departure** | **Breakfast** | 7:30\u202fAM – 8:00\u202fAM. |\n| | **Morning walk at Marble Palace or a quick visit to the St. Paul’s Cathedral** | 8:30\u202fAM – 9:30\u202fAM. |\n| | **Check‑out** | 10:00\u202fAM. |\n| | **Last‑minute shopping at New Market** | 10:30\u202fAM – 11:30\u202fAM. |\n| | **Lunch** | 12:00\u202fPM – 12:45\u202fPM (₹300). |\n| | **Board the return train** | 5:00\u202fPM – 5:00\u202fAM (next day). |\n| | **Arrive back in Mumbai** | 5:00\u202fAM. |\n\n---\n\n##', 'satisfied_with_plan': None}
# DEBUG2: User input in approval: 'okay proceed'
# DEBUG: Direct 'proceed' detected without LLM.
# DEBUG: LLM approval extraction: 'proceed'
# DEBUG: In plan_approval_router, satisfied_with_plan=True
# DEBUG: Plan approved; moving to flight booking.
# DEBUG: Entering ask_flight_details with state {'starting_point': 'mumbai', 'destination': 'Kolkata', 'budget': '18000', 'duration': '3 days', 'proposed_plan': '### 3‑Day “Mumbai\u202f→\u202fKolkata” Adventure on ₹18,000  \n*(All prices are approximate and can vary with season, booking time, and personal choices. I’ve rounded up to give you a comfortable cushion.)*\n\n| Item | Approx. Cost (₹) | Notes |\n|------|------------------|-------|\n| **Mumbai → Kolkata (train, 3‑tier AC)** | 1,800 | Book early on IRCTC or a travel portal. Overnight Rajdhani or Duronto gives you a good seat and meals. |\n| **Kolkata → Mumbai (train, 3‑tier AC)** | 1,800 | Same class, same comfort. |\n| **Accommodation (2 nights, budget hotel/hostel)** | 4,000 | ₹2,000/night (e.g., Hotel Shanti, OYO 3‑star, or a hostel dorm). |\n| **Food (3 days)** | 2,700 | Breakfast ₹200, Lunch ₹300, Dinner ₹400 per day. |\n| **Local transport (auto/metro)** | 600 | ₹200/day for rickshaws, auto, or metro. |\n| **Entrance fees & small extras** | 400 | Museum tickets, temple donations, small souvenirs. |\n| **Buffer & emergencies** | 1,200 | Unexpected taxi, extra snack, or a souvenir. |\n| ****Total** | **≈\u202f18,000** | Leaves a little room for spontaneous fun. |\n\n> **Tip:** If you’re flexible with dates, book your trains at least 4–6\u202fweeks in advance to lock in the lowest fares. Use the “Railway Enquiry” app or IRCTC to compare coaches and choose the one with the best view.\n\n---\n\n## Day‑by‑Day Itinerary\n\n| Time | Activity | Where & How |\n|------|----------|-------------|\n| **Day 0 – Evening** | **Board the overnight train** from Mumbai CST to Sealdah. | 8:00\u202fPM – 8:00\u202fAM (next day). |\n| **Day 1 – Morning** | **Arrive in Kolkata** at 8\u202fAM. | Take a short auto or metro ride to your hotel. |\n| | **Check‑in & refresh** | 10:00\u202fAM – 11:00\u202fAM. |\n| | **Breakfast** | Hotel or a local chai‑tea stall (₹200). |\n| | **Victoria Memorial** | 11:30\u202fAM – 1:30\u202fPM. Take a metro or auto; entrance ₹30. |\n| | **Lunch** | 1:45\u202fPM – 2:30\u202fPM at a local eatery (e.g., Biryani House, ₹300). |\n| | **Howrah Bridge** | 3:00\u202fPM – 3:30\u202fPM. Walk across, capture photos. |\n| | **Park Street** | 4:00\u202fPM – 6:00\u202fPM. Explore cafés, shop for a souvenir. |\n| | **Dinner** | 7:00\u202fPM – 8:30\u202fPM at a budget‑friendly place (e.g., Khandwa, ₹400). |\n| | **Night** | Optional: a short stroll along the river or a quick metro ride back to the hotel. |\n| **Day 2 – Full Day** | **Breakfast** | 8:00\u202fAM – 8:30\u202fAM. |\n| | **Dakshineswar Kali Temple** | 9:00\u202fAM – 10:30\u202fAM. Take a ferry or auto; donation ₹20. |\n| | **Kumartuli** | 11:00\u202fAM – 12:30\u202fPM. Watch artisans at work. |\n| | **Lunch** | 1:00\u202fPM – 1:45\u202fPM at a local spot (₹300). |\n| | **Indian Museum** | 2:30\u202fPM – 4:30\u202fPM. Entrance ₹10. |\n| | **College Street** | 5:00\u202fPM – 6:00\u202fPM. Browse book stalls, grab a snack. |\n| | **Dinner** | 7:00\u202fPM – 8:30\u202fPM at a budget restaurant (₹400). |\n| | **Night** | Relax at the hotel or enjoy a local street food (₹200). |\n| **Day 3 – Morning & Departure** | **Breakfast** | 7:30\u202fAM – 8:00\u202fAM. |\n| | **Morning walk at Marble Palace or a quick visit to the St. Paul’s Cathedral** | 8:30\u202fAM – 9:30\u202fAM. |\n| | **Check‑out** | 10:00\u202fAM. |\n| | **Last‑minute shopping at New Market** | 10:30\u202fAM – 11:30\u202fAM. |\n| | **Lunch** | 12:00\u202fPM – 12:45\u202fPM (₹300). |\n| | **Board the return train** | 5:00\u202fPM – 5:00\u202fAM (next day). |\n| | **Arrive back in Mumbai** | 5:00\u202fAM. |\n\n---\n\n##', 'satisfied_with_plan': True}
# DEBUG: Entering ask_flight_details with state {'starting_point': 'mumbai', 'destination': 'Kolkata', 'budget': '18000', 'duration': '3 days', 'proposed_plan': '### 3‑Day “Mumbai\u202f→\u202fKolkata” Adventure on ₹18,000  \n*(All prices are approximate and can vary with season, booking time, and personal choices. I’ve rounded up to give you a comfortable cushion.)*\n\n| Item | Approx. Cost (₹) | Notes |\n|------|------------------|-------|\n| **Mumbai → Kolkata (train, 3‑tier AC)** | 1,800 | Book early on IRCTC or a travel portal. Overnight Rajdhani or Duronto gives you a good seat and meals. |\n| **Kolkata → Mumbai (train, 3‑tier AC)** | 1,800 | Same class, same comfort. |\n| **Accommodation (2 nights, budget hotel/hostel)** | 4,000 | ₹2,000/night (e.g., Hotel Shanti, OYO 3‑star, or a hostel dorm). |\n| **Food (3 days)** | 2,700 | Breakfast ₹200, Lunch ₹300, Dinner ₹400 per day. |\n| **Local transport (auto/metro)** | 600 | ₹200/day for rickshaws, auto, or metro. |\n| **Entrance fees & small extras** | 400 | Museum tickets, temple donations, small souvenirs. |\n| **Buffer & emergencies** | 1,200 | Unexpected taxi, extra snack, or a souvenir. |\n| ****Total** | **≈\u202f18,000** | Leaves a little room for spontaneous fun. |\n\n> **Tip:** If you’re flexible with dates, book your trains at least 4–6\u202fweeks in advance to lock in the lowest fares. Use the “Railway Enquiry” app or IRCTC to compare coaches and choose the one with the best view.\n\n---\n\n## Day‑by‑Day Itinerary\n\n| Time | Activity | Where & How |\n|------|----------|-------------|\n| **Day 0 – Evening** | **Board the overnight train** from Mumbai CST to Sealdah. | 8:00\u202fPM – 8:00\u202fAM (next day). |\n| **Day 1 – Morning** | **Arrive in Kolkata** at 8\u202fAM. | Take a short auto or metro ride to your hotel. |\n| | **Check‑in & refresh** | 10:00\u202fAM – 11:00\u202fAM. |\n| | **Breakfast** | Hotel or a local chai‑tea stall (₹200). |\n| | **Victoria Memorial** | 11:30\u202fAM – 1:30\u202fPM. Take a metro or auto; entrance ₹30. |\n| | **Lunch** | 1:45\u202fPM – 2:30\u202fPM at a local eatery (e.g., Biryani House, ₹300). |\n| | **Howrah Bridge** | 3:00\u202fPM – 3:30\u202fPM. Walk across, capture photos. |\n| | **Park Street** | 4:00\u202fPM – 6:00\u202fPM. Explore cafés, shop for a souvenir. |\n| | **Dinner** | 7:00\u202fPM – 8:30\u202fPM at a budget‑friendly place (e.g., Khandwa, ₹400). |\n| | **Night** | Optional: a short stroll along the river or a quick metro ride back to the hotel. |\n| **Day 2 – Full Day** | **Breakfast** | 8:00\u202fAM – 8:30\u202fAM. |\n| | **Dakshineswar Kali Temple** | 9:00\u202fAM – 10:30\u202fAM. Take a ferry or auto; donation ₹20. |\n| | **Kumartuli** | 11:00\u202fAM – 12:30\u202fPM. Watch artisans at work. |\n| | **Lunch** | 1:00\u202fPM – 1:45\u202fPM at a local spot (₹300). |\n| | **Indian Museum** | 2:30\u202fPM – 4:30\u202fPM. Entrance ₹10. |\n| | **College Street** | 5:00\u202fPM – 6:00\u202fPM. Browse book stalls, grab a snack. |\n| | **Dinner** | 7:00\u202fPM – 8:30\u202fPM at a budget restaurant (₹400). |\n| | **Night** | Relax at the hotel or enjoy a local street food (₹200). |\n| **Day 3 – Morning & Departure** | **Breakfast** | 7:30\u202fAM – 8:00\u202fAM. |\n| | **Morning walk at Marble Palace or a quick visit to the St. Paul’s Cathedral** | 8:30\u202fAM – 9:30\u202fAM. |\n| | **Check‑out** | 10:00\u202fAM. |\n| | **Last‑minute shopping at New Market** | 10:30\u202fAM – 11:30\u202fAM. |\n| | **Lunch** | 12:00\u202fPM – 12:45\u202fPM (₹300). |\n| | **Board the return train** | 5:00\u202fPM – 5:00\u202fAM (next day). |\n| | **Arrive back in Mumbai** | 5:00\u202fAM. |\n\n---\n\n##', 'satisfied_with_plan': True}
# DEBUG: Entering ask_flight_details with state {'starting_point': 'mumbai', 'destination': 'Kolkata', 'budget': '18000', 'duration': '3 days', 'proposed_plan': '### 3‑Day “Mumbai\u202f→\u202fKolkata” Adventure on ₹18,000  \n*(All prices are approximate and can vary with season, booking time, and personal choices. I’ve rounded up to give you a comfortable cushion.)*\n\n| Item | Approx. Cost (₹) | Notes |\n|------|------------------|-------|\n| **Mumbai → Kolkata (train, 3‑tier AC)** | 1,800 | Book early on IRCTC or a travel portal. Overnight Rajdhani or Duronto gives you a good seat and meals. |\n| **Kolkata → Mumbai (train, 3‑tier AC)** | 1,800 | Same class, same comfort. |\n| **Accommodation (2 nights, budget hotel/hostel)** | 4,000 | ₹2,000/night (e.g., Hotel Shanti, OYO 3‑star, or a hostel dorm). |\n| **Food (3 days)** | 2,700 | Breakfast ₹200, Lunch ₹300, Dinner ₹400 per day. |\n| **Local transport (auto/metro)** | 600 | ₹200/day for rickshaws, auto, or metro. |\n| **Entrance fees & small extras** | 400 | Museum tickets, temple donations, small souvenirs. |\n| **Buffer & emergencies** | 1,200 | Unexpected taxi, extra snack, or a souvenir. |\n| ****Total** | **≈\u202f18,000** | Leaves a little room for spontaneous fun. |\n\n> **Tip:** If you’re flexible with dates, book your trains at least 4–6\u202fweeks in advance to lock in the lowest fares. Use the “Railway Enquiry” app or IRCTC to compare coaches and choose the one with the best view.\n\n---\n\n## Day‑by‑Day Itinerary\n\n| Time | Activity | Where & How |\n|------|----------|-------------|\n| **Day 0 – Evening** | **Board the overnight train** from Mumbai CST to Sealdah. | 8:00\u202fPM – 8:00\u202fAM (next day). |\n| **Day 1 – Morning** | **Arrive in Kolkata** at 8\u202fAM. | Take a short auto or metro ride to your hotel. |\n| | **Check‑in & refresh** | 10:00\u202fAM – 11:00\u202fAM. |\n| | **Breakfast** | Hotel or a local chai‑tea stall (₹200). |\n| | **Victoria Memorial** | 11:30\u202fAM – 1:30\u202fPM. Take a metro or auto; entrance ₹30. |\n| | **Lunch** | 1:45\u202fPM – 2:30\u202fPM at a local eatery (e.g., Biryani House, ₹300). |\n| | **Howrah Bridge** | 3:00\u202fPM – 3:30\u202fPM. Walk across, capture photos. |\n| | **Park Street** | 4:00\u202fPM – 6:00\u202fPM. Explore cafés, shop for a souvenir. |\n| | **Dinner** | 7:00\u202fPM – 8:30\u202fPM at a budget‑friendly place (e.g., Khandwa, ₹400). |\n| | **Night** | Optional: a short stroll along the river or a quick metro ride back to the hotel. |\n| **Day 2 – Full Day** | **Breakfast** | 8:00\u202fAM – 8:30\u202fAM. |\n| | **Dakshineswar Kali Temple** | 9:00\u202fAM – 10:30\u202fAM. Take a ferry or auto; donation ₹20. |\n| | **Kumartuli** | 11:00\u202fAM – 12:30\u202fPM. Watch artisans at work. |\n| | **Lunch** | 1:00\u202fPM – 1:45\u202fPM at a local spot (₹300). |\n| | **Indian Museum** | 2:30\u202fPM – 4:30\u202fPM. Entrance ₹10. |\n| | **College Street** | 5:00\u202fPM – 6:00\u202fPM. Browse book stalls, grab a snack. |\n| | **Dinner** | 7:00\u202fPM – 8:30\u202fPM at a budget restaurant (₹400). |\n| | **Night** | Relax at the hotel or enjoy a local street food (₹200). |\n| **Day 3 – Morning & Departure** | **Breakfast** | 7:30\u202fAM – 8:00\u202fAM. |\n| | **Morning walk at Marble Palace or a quick visit to the St. Paul’s Cathedral** | 8:30\u202fAM – 9:30\u202fAM. |\n| | **Check‑out** | 10:00\u202fAM. |\n| | **Last‑minute shopping at New Market** | 10:30\u202fAM – 11:30\u202fAM. |\n| | **Lunch** | 12:00\u202fPM – 12:45\u202fPM (₹300). |\n| | **Board the return train** | 5:00\u202fPM – 5:00\u202fAM (next day). |\n| | **Arrive back in Mumbai** | 5:00\u202fAM. |\n\n---\n\n##', 'satisfied_with_plan': True}
# DEBUG: Entering ask_flight_details with state {'starting_point': 'mumbai', 'destination': 'Kolkata', 'budget': '18000', 'duration': '3 days', 'proposed_plan': '### 3‑Day “Mumbai\u202f→\u202fKolkata” Adventure on ₹18,000  \n*(All prices are approximate and can vary with season, booking time, and personal choices. I’ve rounded up to give you a comfortable cushion.)*\n\n| Item | Approx. Cost (₹) | Notes |\n|------|------------------|-------|\n| **Mumbai → Kolkata (train, 3‑tier AC)** | 1,800 | Book early on IRCTC or a travel portal. Overnight Rajdhani or Duronto gives you a good seat and meals. |\n| **Kolkata → Mumbai (train, 3‑tier AC)** | 1,800 | Same class, same comfort. |\n| **Accommodation (2 nights, budget hotel/hostel)** | 4,000 | ₹2,000/night (e.g., Hotel Shanti, OYO 3‑star, or a hostel dorm). |\n| **Food (3 days)** | 2,700 | Breakfast ₹200, Lunch ₹300, Dinner ₹400 per day. |\n| **Local transport (auto/metro)** | 600 | ₹200/day for rickshaws, auto, or metro. |\n| **Entrance fees & small extras** | 400 | Museum tickets, temple donations, small souvenirs. |\n| **Buffer & emergencies** | 1,200 | Unexpected taxi, extra snack, or a souvenir. |\n| ****Total** | **≈\u202f18,000** | Leaves a little room for spontaneous fun. |\n\n> **Tip:** If you’re flexible with dates, book your trains at least 4–6\u202fweeks in advance to lock in the lowest fares. Use the “Railway Enquiry” app or IRCTC to compare coaches and choose the one with the best view.\n\n---\n\n## Day‑by‑Day Itinerary\n\n| Time | Activity | Where & How |\n|------|----------|-------------|\n| **Day 0 – Evening** | **Board the overnight train** from Mumbai CST to Sealdah. | 8:00\u202fPM – 8:00\u202fAM (next day). |\n| **Day 1 – Morning** | **Arrive in Kolkata** at 8\u202fAM. | Take a short auto or metro ride to your hotel. |\n| | **Check‑in & refresh** | 10:00\u202fAM – 11:00\u202fAM. |\n| | **Breakfast** | Hotel or a local chai‑tea stall (₹200). |\n| | **Victoria Memorial** | 11:30\u202fAM – 1:30\u202fPM. Take a metro or auto; entrance ₹30. |\n| | **Lunch** | 1:45\u202fPM – 2:30\u202fPM at a local eatery (e.g., Biryani House, ₹300). |\n| | **Howrah Bridge** | 3:00\u202fPM – 3:30\u202fPM. Walk across, capture photos. |\n| | **Park Street** | 4:00\u202fPM – 6:00\u202fPM. Explore cafés, shop for a souvenir. |\n| | **Dinner** | 7:00\u202fPM – 8:30\u202fPM at a budget‑friendly place (e.g., Khandwa, ₹400). |\n| | **Night** | Optional: a short stroll along the river or a quick metro ride back to the hotel. |\n| **Day 2 – Full Day** | **Breakfast** | 8:00\u202fAM – 8:30\u202fAM. |\n| | **Dakshineswar Kali Temple** | 9:00\u202fAM – 10:30\u202fAM. Take a ferry or auto; donation ₹20. |\n| | **Kumartuli** | 11:00\u202fAM – 12:30\u202fPM. Watch artisans at work. |\n| | **Lunch** | 1:00\u202fPM – 1:45\u202fPM at a local spot (₹300). |\n| | **Indian Museum** | 2:30\u202fPM – 4:30\u202fPM. Entrance ₹10. |\n| | **College Street** | 5:00\u202fPM – 6:00\u202fPM. Browse book stalls, grab a snack. |\n| | **Dinner** | 7:00\u202fPM – 8:30\u202fPM at a budget restaurant (₹400). |\n| | **Night** | Relax at the hotel or enjoy a local street food (₹200). |\n| **Day 3 – Morning & Departure** | **Breakfast** | 7:30\u202fAM – 8:00\u202fAM. |\n| | **Morning walk at Marble Palace or a quick visit to the St. Paul’s Cathedral** | 8:30\u202fAM – 9:30\u202fAM. |\n| | **Check‑out** | 10:00\u202fAM. |\n| | **Last‑minute shopping at New Market** | 10:30\u202fAM – 11:30\u202fAM. |\n| | **Lunch** | 12:00\u202fPM – 12:45\u202fPM (₹300). |\n| | **Board the return train** | 5:00\u202fPM – 5:00\u202fAM (next day). |\n| | **Arrive back in Mumbai** | 5:00\u202fAM. |\n\n---\n\n##', 'satisfied_with_plan': True}
# DEBUG: Entering ask_flight_details with state {'starting_point': 'mumbai', 'destination': 'Kolkata', 'budget': '18000', 'duration': '3 days', 'proposed_plan': '### 3‑Day “Mumbai\u202f→\u202fKolkata” Adventure on ₹18,000  \n*(All prices are approximate and can vary with season, booking time, and personal choices. I’ve rounded up to give you a comfortable cushion.)*\n\n| Item | Approx. Cost (₹) | Notes |\n|------|------------------|-------|\n| **Mumbai → Kolkata (train, 3‑tier AC)** | 1,800 | Book early on IRCTC or a travel portal. Overnight Rajdhani or Duronto gives you a good seat and meals. |\n| **Kolkata → Mumbai (train, 3‑tier AC)** | 1,800 | Same class, same comfort. |\n| **Accommodation (2 nights, budget hotel/hostel)** | 4,000 | ₹2,000/night (e.g., Hotel Shanti, OYO 3‑star, or a hostel dorm). |\n| **Food (3 days)** | 2,700 | Breakfast ₹200, Lunch ₹300, Dinner ₹400 per day. |\n| **Local transport (auto/metro)** | 600 | ₹200/day for rickshaws, auto, or metro. |\n| **Entrance fees & small extras** | 400 | Museum tickets, temple donations, small souvenirs. |\n| **Buffer & emergencies** | 1,200 | Unexpected taxi, extra snack, or a souvenir. |\n| ****Total** | **≈\u202f18,000** | Leaves a little room for spontaneous fun. |\n\n> **Tip:** If you’re flexible with dates, book your trains at least 4–6\u202fweeks in advance to lock in the lowest fares. Use the “Railway Enquiry” app or IRCTC to compare coaches and choose the one with the best view.\n\n---\n\n## Day‑by‑Day Itinerary\n\n| Time | Activity | Where & How |\n|------|----------|-------------|\n| **Day 0 – Evening** | **Board the overnight train** from Mumbai CST to Sealdah. | 8:00\u202fPM – 8:00\u202fAM (next day). |\n| **Day 1 – Morning** | **Arrive in Kolkata** at 8\u202fAM. | Take a short auto or metro ride to your hotel. |\n| | **Check‑in & refresh** | 10:00\u202fAM – 11:00\u202fAM. |\n| | **Breakfast** | Hotel or a local chai‑tea stall (₹200). |\n| | **Victoria Memorial** | 11:30\u202fAM – 1:30\u202fPM. Take a metro or auto; entrance ₹30. |\n| | **Lunch** | 1:45\u202fPM – 2:30\u202fPM at a local eatery (e.g., Biryani House, ₹300). |\n| | **Howrah Bridge** | 3:00\u202fPM – 3:30\u202fPM. Walk across, capture photos. |\n| | **Park Street** | 4:00\u202fPM – 6:00\u202fPM. Explore cafés, shop for a souvenir. |\n| | **Dinner** | 7:00\u202fPM – 8:30\u202fPM at a budget‑friendly place (e.g., Khandwa, ₹400). |\n| | **Night** | Optional: a short stroll along the river or a quick metro ride back to the hotel. |\n| **Day 2 – Full Day** | **Breakfast** | 8:00\u202fAM – 8:30\u202fAM. |\n| | **Dakshineswar Kali Temple** | 9:00\u202fAM – 10:30\u202fAM. Take a ferry or auto; donation ₹20. |\n| | **Kumartuli** | 11:00\u202fAM – 12:30\u202fPM. Watch artisans at work. |\n| | **Lunch** | 1:00\u202fPM – 1:45\u202fPM at a local spot (₹300). |\n| | **Indian Museum** | 2:30\u202fPM – 4:30\u202fPM. Entrance ₹10. |\n| | **College Street** | 5:00\u202fPM – 6:00\u202fPM. Browse book stalls, grab a snack. |\n| | **Dinner** | 7:00\u202fPM – 8:30\u202fPM at a budget restaurant (₹400). |\n| | **Night** | Relax at the hotel or enjoy a local street food (₹200). |\n| **Day 3 – Morning & Departure** | **Breakfast** | 7:30\u202fAM – 8:00\u202fAM. |\n| | **Morning walk at Marble Palace or a quick visit to the St. Paul’s Cathedral** | 8:30\u202fAM – 9:30\u202fAM. |\n| | **Check‑out** | 10:00\u202fAM. |\n| | **Last‑minute shopping at New Market** | 10:30\u202fAM – 11:30\u202fAM. |\n| | **Lunch** | 12:00\u202fPM – 12:45\u202fPM (₹300). |\n| | **Board the return train** | 5:00\u202fPM – 5:00\u202fAM (next day). |\n| | **Arrive back in Mumbai** | 5:00\u202fAM. |\n\n---\n\n##', 'satisfied_with_plan': True}
# DEBUG: Fetching flights mumbai → kolkata on 2026-01-10
# DEBUG: Fetching flights mumbai → kolkata on 2026-01-10
# DEBUG: Flight selected successfully
# DEBUG booking_confirmation selected_flight: {'id': '77fd3a601a59cb5033574c408d2046ab7b3df7a5cce8ff6785cc80ceb3011f4b', 'careerCode': 'IX', 'flight_code': 'IX-1176', 'flight_name': 'Air India Express', 'stops': '1 Stop', 'cabinType': 'Economy', 'baggage': {'cabin': {'code': None, 'qty': 1, 'quantity': None, 'dimensions': None, 'unit': 'KG', 'text': '7 KG', 'allowance': 7, 'refNumber': None, 'totalWeight': None, 'perPieceWeight': None, 'perPieceWeightFlag': None}, 'checkIn': None, 'underSeat': None, 'baggageOptionsAvailable': True}, 'currency': 'INR', 'departureAirport': {'time': '2026-01-10T07:10:00', 'code': 'BOM', 'tz': 'Asia/Kolkata', 'timeZone': '5.50', 'type': '1', 'label': 'Chhatrapati Shivaji International Airport', 'country': {'label': 'India', 'code': 'IN'}, 'city': 'Mumbai'}, 'arrivalAirport': {'time': '2026-01-10T20:10:00', 'code': 'CCU', 'tz': 'Asia/Kolkata', 'timeZone': '5.50', 'type': '2', 'label': 'Netaji Subhas Chandra Bose International Airport', 'country': {'label': 'India', 'code': 'IN'}, 'city': 'Kolkata'}, 'path': ['IX-1176', 'IX-1532'], 'duration': {'text': '13h 00m', 'value': 780, 'unit': None}, 'stopSummary': {'0': {'airport': 'IXB', 'stopDuration': 545}, 'connectingTime': None}, 'totals': {'currency': 'INR', 'baggage': None, 'penalty': None, 'total': 11019.53204, 'tax': None, 'base': 11019.53204}}
# DEBUG booking_confirmation selected_flight: {'id': '77fd3a601a59cb5033574c408d2046ab7b3df7a5cce8ff6785cc80ceb3011f4b', 'careerCode': 'IX', 'flight_code': 'IX-1176', 'flight_name': 'Air India Express', 'stops': '1 Stop', 'cabinType': 'Economy', 'baggage': {'cabin': {'code': None, 'qty': 1, 'quantity': None, 'dimensions': None, 'unit': 'KG', 'text': '7 KG', 'allowance': 7, 'refNumber': None, 'totalWeight': None, 'perPieceWeight': None, 'perPieceWeightFlag': None}, 'checkIn': None, 'underSeat': None, 'baggageOptionsAvailable': True}, 'currency': 'INR', 'departureAirport': {'time': '2026-01-10T07:10:00', 'code': 'BOM', 'tz': 'Asia/Kolkata', 'timeZone': '5.50', 'type': '1', 'label': 'Chhatrapati Shivaji International Airport', 'country': {'label': 'India', 'code': 'IN'}, 'city': 'Mumbai'}, 'arrivalAirport': {'time': '2026-01-10T20:10:00', 'code': 'CCU', 'tz': 'Asia/Kolkata', 'timeZone': '5.50', 'type': '2', 'label': 'Netaji Subhas Chandra Bose International Airport', 'country': {'label': 'India', 'code': 'IN'}, 'city': 'Kolkata'}, 'path': ['IX-1176', 'IX-1532'], 'duration': {'text': '13h 00m', 'value': 780, 'unit': None}, 'stopSummary': {'0': {'airport': 'IXB', 'stopDuration': 545}, 'connectingTime': None}, 'totals': {'currency': 'INR', 'baggage': None, 'penalty': None, 'total': 11019.53204, 'tax': None, 'base': 11019.53204}}
# ✅ Booking confirmed for Air India Express (IX-1176)!
# Trip complete!

# %%
ans= get_airport_code("mumbai")
ans
# Out:
# 'BOM'

# %%
fetch_flights()

# %%
RAPIDAPI_KEY = ""

url = "https://flight-fare-search.p.rapidapi.com/v2/flights/"
querystring = {
    "from": 'BOM',
    "to": 'CCU',
    "date": "2026-01-10",
    "adult": "1",
    "type": "economy",
    "currency": "INR"
}

headers = {
    "x-rapidapi-key": RAPIDAPI_KEY,
    "x-rapidapi-host": "flight-fare-search.p.rapidapi.com"
}

try:
    response = requests.get(url, headers=headers, params=querystring, timeout=20)
    flights = response.json().get("results", [])[:4]
    print(flights)
except Exception as e:
    print("ERROR fetching flights:", e)
    flights = []
# Out:
# []
